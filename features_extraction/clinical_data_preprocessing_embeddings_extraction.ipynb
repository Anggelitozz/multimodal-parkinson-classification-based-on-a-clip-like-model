# %% [markdown]
# # IMPORTS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, roc_auc_score, confusion_matrix)
from sentence_transformers import SentenceTransformer
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {device}")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Usando dispositivo: cpu

# %% [markdown]
# # PROMPTS

# %%
import pandas as pd

# Cargar dataset
data = pd.read_csv("/content/drive/MyDrive/avances/cvs/originales/MDS-UPDRS_Part_III_28Oct2025_estandarizado_pd_mbrs (1).csv")
df_parkinson = pd.DataFrame(data)

# Agregar columna 'grupo' con todos los valores en 1
df_parkinson["grupo"] = 1

# Diccionario de descripciones en español
descripciones_es = {
    'Edad': 'edad', 'Genero': 'género', 'NP3BRADY': 'bradicinesia',
    'NP3FACXP': 'expresión facial reducida', 'NP3FRZGT': 'freezing de la marcha',
    'NP3FTAPL': 'tapping pie izquierdo', 'NP3FTAPR': 'tapping pie derecho',
    'NP3GAIT': 'alteración de la marcha', 'NP3HMOVL': 'movimiento mano izquierda',
    'NP3HMOVR': 'movimiento mano derecha', 'NP3KTRML': 'kinésia mano izquierda',
    'NP3KTRMR': 'kinésia mano derecha', 'NP3LGAGL': 'agilidad pierna izquierda',
    'NP3LGAGR': 'agilidad pierna derecha', 'NP3POSTR': 'postura',
    'NP3PRSPL': 'temblor postural mano izquierda', 'NP3PRSPR': 'temblor postural mano derecha',
    'NP3PSTBL': 'inestabilidad postural', 'NP3PTRML': 'temblor de reposo mano izquierda',
    'NP3PTRMR': 'temblor de reposo mano derecha', 'NP3RIGLL': 'rigidez pierna izquierda',
    'NP3RIGLU': 'rigidez brazo izquierdo', 'NP3RIGN': 'rigidez cuello',
    'NP3RIGRL': 'rigidez pierna derecha', 'NP3RIGRU': 'rigidez brazo derecho',
    'NP3RISNG': 'dificultad para levantarse', 'NP3RTALJ': 'temblor de acción pierna izquierda',
    'NP3RTALL': 'temblor de acción pierna izquierda', 'NP3RTALU': 'temblor de acción brazo izquierdo',
    'NP3RTARL': 'temblor de acción pierna derecha', 'NP3RTARU': 'temblor de acción brazo derecho',
    'NP3RTCON': 'constancia del temblor', 'NP3SPCH': 'alteración del habla',
    'NP3TOT': 'puntuación total MDS-UPDRS III', 'NP3TTAPL': 'tapping mano izquierda',
    'NP3TTAPR': 'tapping mano derecha', 'DBSYN': 'síntomas de estimulación cerebral',
    'DYSKPRES': 'presencia de discinesias', 'MBRS': 'escala de discinesias',
    'H & Y Stage': 'estadio Hoehn & Yahr', 'NHY': 'estadio Hoehn & Yahr numérico',
    'DBSOFFTM': 'tiempo de suspensión del tratamiento DBS', 'DBSONTM': 'tiempo de inicio del tratamiento DBS',
    'HRDBSOFF': 'horas entre el apagado del DBS y el examen NUPDRS3',
    'HRDBSON': 'horas entre el encendido del DBS y el examen NUPDRS3',
    'HRPOSTMED': 'horas entre la última dosis de medicación para EP y el examen NUPDRS3',
    'OFFEXAM': 'examen OFF realizado', 'OFFNORSN': 'motivo no realizado examen OFF',
    'ONEXAM': 'examen ON realizado', 'ONNORSN': 'motivo no realizado examen ON',
    'ONOFFORDER': 'primer examen de la Parte III OFF o ON', 'PDMEDYN': 'medicación para la EP',
    'PDSTATE': 'estado funcional actual', 'PDTRTMNT': 'tratamiento recibido',
    'Pat_id': 'ID del paciente', 'grupo': 'grupo del paciente'
}

# Diccionario de descripciones en inglés
descripciones_en = {
    'Edad': 'age', 'Genero': 'gender', 'NP3BRADY': 'bradykinesia',
    'NP3FACXP': 'reduced facial expression', 'NP3FRZGT': 'freezing of gait',
    'NP3FTAPL': 'left foot tapping', 'NP3FTAPR': 'right foot tapping',
    'NP3GAIT': 'gait impairment', 'NP3HMOVL': 'left hand movement',
    'NP3HMOVR': 'right hand movement', 'NP3KTRML': 'left hand kinesia',
    'NP3KTRMR': 'right hand kinesia', 'NP3LGAGL': 'left leg agility',
    'NP3LGAGR': 'right leg agility', 'NP3POSTR': 'posture',
    'NP3PRSPL': 'left hand postural tremor', 'NP3PRSPR': 'right hand postural tremor',
    'NP3PSTBL': 'postural instability', 'NP3PTRML': 'left hand resting tremor',
    'NP3PTRMR': 'right hand resting tremor', 'NP3RIGLL': 'left leg rigidity',
    'NP3RIGLU': 'left arm rigidity', 'NP3RIGN': 'neck rigidity',
    'NP3RIGRL': 'right leg rigidity', 'NP3RIGRU': 'right arm rigidity',
    'NP3RISNG': 'difficulty rising from chair', 'NP3RTALJ': 'left leg action tremor',
    'NP3RTALL': 'left leg action tremor', 'NP3RTALU': 'left arm action tremor',
    'NP3RTARL': 'right leg action tremor', 'NP3RTARU': 'right arm action tremor',
    'NP3RTCON': 'tremor constancy', 'NP3SPCH': 'speech impairment',
    'NP3TOT': 'MDS-UPDRS III total score', 'NP3TTAPL': 'left hand tapping',
    'NP3TTAPR': 'right hand tapping', 'DBSYN': 'deep brain stimulation symptoms',
    'DYSKPRES': 'dyskinesia presence', 'MBRS': 'dyskinesia scale',
    'H & Y Stage': 'Hoehn & Yahr stage', 'NHY': 'numeric Hoehn & Yahr stage',
    'DBSOFFTM': 'time DBS switched off', 'DBSONTM': 'time DBS switched on',
    'HRDBSOFF': 'hours from DBS off to NUPDRS3 exam',
    'HRDBSON': 'hours from DBS on to NUPDRS3 exam',
    'HRPOSTMED': 'hours from last PD medication to NUPDRS3 exam',
    'OFFEXAM': 'OFF exam performed', 'OFFNORSN': 'reason OFF exam not performed',
    'ONEXAM': 'ON exam performed', 'ONNORSN': 'reason ON exam not performed',
    'ONOFFORDER': 'order of OFF/ON Part III exams', 'PDMEDYN': 'Parkinson medication',
    'PDSTATE': 'current functional state', 'PDTRTMNT': 'treatment received',
    'Pat_id': 'patient ID', 'grupo': 'patient group'
}

def crear_prompts_parkinson(df, descripciones, idioma="es"):
    prompts = []
    for _, row in df.iterrows():
        if idioma == "es":
            tipo_paciente = "paciente con Parkinson" if row['grupo'] == 1 else "control"
        else:
            tipo_paciente = "Parkinson's patient" if row['grupo'] == 1 else "control subject"

        prompt_parts = [f"{tipo_paciente}:"]

        for col in df.columns:
            valor = row[col]

            if pd.isna(valor):
                valor = "no informado" if idioma == "es" else "not reported"
            else:
                if col == 'Genero':
                    if idioma == "es":
                        valor = "masculino" if valor == 1 else "femenino"
                    else:
                        valor = "male" if valor == 1 else "female"

            if col in descripciones:
                desc = descripciones[col]
                prompt_parts.append(f"{desc}: {valor}")
            else:
                prompt_parts.append(f"{col}: {valor}")

        prompts.append(". ".join(prompt_parts))
    return prompts

# Guardar prompts en español e inglés en columnas del DataFrame
df_parkinson["prompts_400"] = crear_prompts_parkinson(df_parkinson, descripciones_es, idioma="es")
df_parkinson["prompts_400_ing"] = crear_prompts_parkinson(df_parkinson, descripciones_en, idioma="en")

# Opcional: ver primeros 3 de cada uno
for i in range(3):
    print(f"\nPaciente {i+1} (ES):\n{df_parkinson['prompts_400'].iloc[i]}")
    print(f"\nPaciente {i+1} (EN):\n{df_parkinson['prompts_400_ing'].iloc[i]}")
# Out:
# Paciente 1 (ES):
# paciente con Parkinson:. PATNO: 3001. EVENT_ID: V17. tratamiento recibido: 1.0. estado funcional actual: 1.0. horas entre la última dosis de medicación para EP y el examen NUPDRS3: 1.0. horas entre el encendido del DBS y el examen NUPDRS3: no informado. horas entre el apagado del DBS y el examen NUPDRS3: no informado. medicación para la EP: 1.0. síntomas de estimulación cerebral: 0.0. primer examen de la Parte III OFF o ON: 1.0. examen OFF realizado: no informado. motivo no realizado examen OFF: no informado. DBSOFFYN: no informado. tiempo de suspensión del tratamiento DBS: no informado. examen ON realizado: 1.0. motivo no realizado examen ON: no informado. HIFUYN: no informado. DBSONYN: no informado. tiempo de inicio del tratamiento DBS: no informado. alteración del habla: 2.0. expresión facial reducida: 1.0. rigidez cuello: 3.0. rigidez brazo derecho: 1.0. rigidez brazo izquierdo: 2.0. rigidez pierna derecha: 1.0. rigidez pierna izquierda: 2.0. tapping pie derecho: 3.0. tapping pie izquierdo: 2.0. movimiento mano derecha: 3.0. movimiento mano izquierda: 2.0. temblor postural mano derecha: 2.0. temblor postural mano izquierda: 1.0. tapping mano derecha: 1.0. tapping mano izquierda: 1.0. agilidad pierna derecha: 2.0. agilidad pierna izquierda: 1.0. dificultad para levantarse: 0.0. alteración de la marcha: 1.0. freezing de la marcha: 0.0. inestabilidad postural: 0.0. postura: 3.0. bradicinesia: 1.0. temblor de reposo mano derecha: 1.0. temblor de reposo mano izquierda: 1.0. kinésia mano derecha: 2.0. kinésia mano izquierda: 1.0. temblor de acción brazo derecho: 0.0. temblor de acción brazo izquierdo: 0.0. temblor de acción pierna derecha: 0.0. temblor de acción pierna izquierda: 0.0. temblor de acción pierna izquierda: 0.0. constancia del temblor: 0.0. puntuación total MDS-UPDRS III: 40.0. presencia de discinesias: 1.0. DYSKIRAT: 0.0. estadio Hoehn & Yahr numérico: 2.0. SEX: 1. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. escala de discinesias: 13.0. grupo del paciente: 1
#
# Paciente 1 (EN):
# Parkinson's patient:. PATNO: 3001. EVENT_ID: V17. treatment received: 1.0. current functional state: 1.0. hours from last PD medication to NUPDRS3 exam: 1.0. hours from DBS on to NUPDRS3 exam: not reported. hours from DBS off to NUPDRS3 exam: not reported. Parkinson medication: 1.0. deep brain stimulation symptoms: 0.0. order of OFF/ON Part III exams: 1.0. OFF exam performed: not reported. reason OFF exam not performed: not reported. DBSOFFYN: not reported. time DBS switched off: not reported. ON exam performed: 1.0. reason ON exam not performed: not reported. HIFUYN: not reported. DBSONYN: not reported. time DBS switched on: not reported. speech impairment: 2.0. reduced facial expression: 1.0. neck rigidity: 3.0. right arm rigidity: 1.0. left arm rigidity: 2.0. right leg rigidity: 1.0. left leg rigidity: 2.0. right foot tapping: 3.0. left foot tapping: 2.0. right hand movement: 3.0. left hand movement: 2.0. right hand postural tremor: 2.0. left hand postural tremor: 1.0. right hand tapping: 1.0. left hand tapping: 1.0. right leg agility: 2.0. left leg agility: 1.0. difficulty rising from chair: 0.0. gait impairment: 1.0. freezing of gait: 0.0. postural instability: 0.0. posture: 3.0. bradykinesia: 1.0. right hand resting tremor: 1.0. left hand resting tremor: 1.0. right hand kinesia: 2.0. left hand kinesia: 1.0. right arm action tremor: 0.0. left arm action tremor: 0.0. right leg action tremor: 0.0. left leg action tremor: 0.0. left leg action tremor: 0.0. tremor constancy: 0.0. MDS-UPDRS III total score: 40.0. dyskinesia presence: 1.0. DYSKIRAT: 0.0. numeric Hoehn & Yahr stage: 2.0. SEX: 1. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. dyskinesia scale: 13.0. patient group: 1. prompts_400: paciente con Parkinson:. PATNO: 3001. EVENT_ID: V17. tratamiento recibido: 1.0. estado funcional actual: 1.0. horas entre la última dosis de medicación para EP y el examen NUPDRS3: 1.0. horas entre el encendido del DBS y el examen NUPDRS3: no informado. horas entre el apagado del DBS y el examen NUPDRS3: no informado. medicación para la EP: 1.0. síntomas de estimulación cerebral: 0.0. primer examen de la Parte III OFF o ON: 1.0. examen OFF realizado: no informado. motivo no realizado examen OFF: no informado. DBSOFFYN: no informado. tiempo de suspensión del tratamiento DBS: no informado. examen ON realizado: 1.0. motivo no realizado examen ON: no informado. HIFUYN: no informado. DBSONYN: no informado. tiempo de inicio del tratamiento DBS: no informado. alteración del habla: 2.0. expresión facial reducida: 1.0. rigidez cuello: 3.0. rigidez brazo derecho: 1.0. rigidez brazo izquierdo: 2.0. rigidez pierna derecha: 1.0. rigidez pierna izquierda: 2.0. tapping pie derecho: 3.0. tapping pie izquierdo: 2.0. movimiento mano derecha: 3.0. movimiento mano izquierda: 2.0. temblor postural mano derecha: 2.0. temblor postural mano izquierda: 1.0. tapping mano derecha: 1.0. tapping mano izquierda: 1.0. agilidad pierna derecha: 2.0. agilidad pierna izquierda: 1.0. dificultad para levantarse: 0.0. alteración de la marcha: 1.0. freezing de la marcha: 0.0. inestabilidad postural: 0.0. postura: 3.0. bradicinesia: 1.0. temblor de reposo mano derecha: 1.0. temblor de reposo mano izquierda: 1.0. kinésia mano derecha: 2.0. kinésia mano izquierda: 1.0. temblor de acción brazo derecho: 0.0. temblor de acción brazo izquierdo: 0.0. temblor de acción pierna derecha: 0.0. temblor de acción pierna izquierda: 0.0. temblor de acción pierna izquierda: 0.0. constancia del temblor: 0.0. puntuación total MDS-UPDRS III: 40.0. presencia de discinesias: 1.0. DYSKIRAT: 0.0. estadio Hoehn & Yahr numérico: 2.0. SEX: 1. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. escala de discinesias: 13.0. grupo del paciente: 1
#
# Paciente 2 (ES):
# paciente con Parkinson:. PATNO: 3002. EVENT_ID: V17. tratamiento recibido: 1.0. estado funcional actual: 1.0. horas entre la última dosis de medicación para EP y el examen NUPDRS3: 0.8333. horas entre el encendido del DBS y el examen NUPDRS3: no informado. horas entre el apagado del DBS y el examen NUPDRS3: no informado. medicación para la EP: 1.0. síntomas de estimulación cerebral: 0.0. primer examen de la Parte III OFF o ON: 1.0. examen OFF realizado: no informado. motivo no realizado examen OFF: no informado. DBSOFFYN: no informado. tiempo de suspensión del tratamiento DBS: no informado. examen ON realizado: 1.0. motivo no realizado examen ON: no informado. HIFUYN: no informado. DBSONYN: no informado. tiempo de inicio del tratamiento DBS: no informado. alteración del habla: 1.0. expresión facial reducida: 1.0. rigidez cuello: 0.0. rigidez brazo derecho: 1.0. rigidez brazo izquierdo: 0.0. rigidez pierna derecha: 0.0. rigidez pierna izquierda: 0.0. tapping pie derecho: 3.0. tapping pie izquierdo: 2.0. movimiento mano derecha: 3.0. movimiento mano izquierda: 2.0. temblor postural mano derecha: 2.0. temblor postural mano izquierda: 2.0. tapping mano derecha: 1.0. tapping mano izquierda: 1.0. agilidad pierna derecha: 1.0. agilidad pierna izquierda: 1.0. dificultad para levantarse: 1.0. alteración de la marcha: 3.0. freezing de la marcha: 0.0. inestabilidad postural: 3.0. postura: 2.0. bradicinesia: 1.0. temblor de reposo mano derecha: 0.0. temblor de reposo mano izquierda: 0.0. kinésia mano derecha: 0.0. kinésia mano izquierda: 0.0. temblor de acción brazo derecho: 0.0. temblor de acción brazo izquierdo: 0.0. temblor de acción pierna derecha: 0.0. temblor de acción pierna izquierda: 0.0. temblor de acción pierna izquierda: 0.0. constancia del temblor: 0.0. puntuación total MDS-UPDRS III: 31.0. presencia de discinesias: 1.0. DYSKIRAT: 0.0. estadio Hoehn & Yahr numérico: 3.0. SEX: 0. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. escala de discinesias: 14.0. grupo del paciente: 1
#
# Paciente 2 (EN):
# Parkinson's patient:. PATNO: 3002. EVENT_ID: V17. treatment received: 1.0. current functional state: 1.0. hours from last PD medication to NUPDRS3 exam: 0.8333. hours from DBS on to NUPDRS3 exam: not reported. hours from DBS off to NUPDRS3 exam: not reported. Parkinson medication: 1.0. deep brain stimulation symptoms: 0.0. order of OFF/ON Part III exams: 1.0. OFF exam performed: not reported. reason OFF exam not performed: not reported. DBSOFFYN: not reported. time DBS switched off: not reported. ON exam performed: 1.0. reason ON exam not performed: not reported. HIFUYN: not reported. DBSONYN: not reported. time DBS switched on: not reported. speech impairment: 1.0. reduced facial expression: 1.0. neck rigidity: 0.0. right arm rigidity: 1.0. left arm rigidity: 0.0. right leg rigidity: 0.0. left leg rigidity: 0.0. right foot tapping: 3.0. left foot tapping: 2.0. right hand movement: 3.0. left hand movement: 2.0. right hand postural tremor: 2.0. left hand postural tremor: 2.0. right hand tapping: 1.0. left hand tapping: 1.0. right leg agility: 1.0. left leg agility: 1.0. difficulty rising from chair: 1.0. gait impairment: 3.0. freezing of gait: 0.0. postural instability: 3.0. posture: 2.0. bradykinesia: 1.0. right hand resting tremor: 0.0. left hand resting tremor: 0.0. right hand kinesia: 0.0. left hand kinesia: 0.0. right arm action tremor: 0.0. left arm action tremor: 0.0. right leg action tremor: 0.0. left leg action tremor: 0.0. left leg action tremor: 0.0. tremor constancy: 0.0. MDS-UPDRS III total score: 31.0. dyskinesia presence: 1.0. DYSKIRAT: 0.0. numeric Hoehn & Yahr stage: 3.0. SEX: 0. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. dyskinesia scale: 14.0. patient group: 1. prompts_400: paciente con Parkinson:. PATNO: 3002. EVENT_ID: V17. tratamiento recibido: 1.0. estado funcional actual: 1.0. horas entre la última dosis de medicación para EP y el examen NUPDRS3: 0.8333. horas entre el encendido del DBS y el examen NUPDRS3: no informado. horas entre el apagado del DBS y el examen NUPDRS3: no informado. medicación para la EP: 1.0. síntomas de estimulación cerebral: 0.0. primer examen de la Parte III OFF o ON: 1.0. examen OFF realizado: no informado. motivo no realizado examen OFF: no informado. DBSOFFYN: no informado. tiempo de suspensión del tratamiento DBS: no informado. examen ON realizado: 1.0. motivo no realizado examen ON: no informado. HIFUYN: no informado. DBSONYN: no informado. tiempo de inicio del tratamiento DBS: no informado. alteración del habla: 1.0. expresión facial reducida: 1.0. rigidez cuello: 0.0. rigidez brazo derecho: 1.0. rigidez brazo izquierdo: 0.0. rigidez pierna derecha: 0.0. rigidez pierna izquierda: 0.0. tapping pie derecho: 3.0. tapping pie izquierdo: 2.0. movimiento mano derecha: 3.0. movimiento mano izquierda: 2.0. temblor postural mano derecha: 2.0. temblor postural mano izquierda: 2.0. tapping mano derecha: 1.0. tapping mano izquierda: 1.0. agilidad pierna derecha: 1.0. agilidad pierna izquierda: 1.0. dificultad para levantarse: 1.0. alteración de la marcha: 3.0. freezing de la marcha: 0.0. inestabilidad postural: 3.0. postura: 2.0. bradicinesia: 1.0. temblor de reposo mano derecha: 0.0. temblor de reposo mano izquierda: 0.0. kinésia mano derecha: 0.0. kinésia mano izquierda: 0.0. temblor de acción brazo derecho: 0.0. temblor de acción brazo izquierdo: 0.0. temblor de acción pierna derecha: 0.0. temblor de acción pierna izquierda: 0.0. temblor de acción pierna izquierda: 0.0. constancia del temblor: 0.0. puntuación total MDS-UPDRS III: 31.0. presencia de discinesias: 1.0. DYSKIRAT: 0.0. estadio Hoehn & Yahr numérico: 3.0. SEX: 0. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. escala de discinesias: 14.0. grupo del paciente: 1
#
# Paciente 3 (ES):
# paciente con Parkinson:. PATNO: 3003. EVENT_ID: V21. tratamiento recibido: 1.0. estado funcional actual: 1.0. horas entre la última dosis de medicación para EP y el examen NUPDRS3: 1.25. horas entre el encendido del DBS y el examen NUPDRS3: no informado. horas entre el apagado del DBS y el examen NUPDRS3: no informado. medicación para la EP: 1.0. síntomas de estimulación cerebral: 0.0. primer examen de la Parte III OFF o ON: no informado. examen OFF realizado: no informado. motivo no realizado examen OFF: no informado. DBSOFFYN: no informado. tiempo de suspensión del tratamiento DBS: no informado. examen ON realizado: 1.0. motivo no realizado examen ON: no informado. HIFUYN: 0.0. DBSONYN: no informado. tiempo de inicio del tratamiento DBS: no informado. alteración del habla: 1.0. expresión facial reducida: 1.0. rigidez cuello: 2.0. rigidez brazo derecho: 2.0. rigidez brazo izquierdo: 1.0. rigidez pierna derecha: 1.0. rigidez pierna izquierda: 0.0. tapping pie derecho: 1.0. tapping pie izquierdo: 1.0. movimiento mano derecha: 2.0. movimiento mano izquierda: 2.0. temblor postural mano derecha: 1.0. temblor postural mano izquierda: 1.0. tapping mano derecha: 1.0. tapping mano izquierda: 1.0. agilidad pierna derecha: 1.0. agilidad pierna izquierda: 1.0. dificultad para levantarse: 0.0. alteración de la marcha: 1.0. freezing de la marcha: 0.0. inestabilidad postural: 0.0. postura: 2.0. bradicinesia: 1.0. temblor de reposo mano derecha: 0.0. temblor de reposo mano izquierda: 0.0. kinésia mano derecha: 1.0. kinésia mano izquierda: 0.0. temblor de acción brazo derecho: 0.0. temblor de acción brazo izquierdo: 0.0. temblor de acción pierna derecha: 0.0. temblor de acción pierna izquierda: 0.0. temblor de acción pierna izquierda: 0.0. constancia del temblor: 0.0. puntuación total MDS-UPDRS III: 25.0. presencia de discinesias: 1.0. DYSKIRAT: 0.0. estadio Hoehn & Yahr numérico: 2.0. SEX: 0. AGE_AT_VISIT: 63.9. COHORT_DEFINITION: Parkinson's Disease. escala de discinesias: 8.0. grupo del paciente: 1
#
# Paciente 3 (EN):
# Parkinson's patient:. PATNO: 3003. EVENT_ID: V21. treatment received: 1.0. current functional state: 1.0. hours from last PD medication to NUPDRS3 exam: 1.25. hours from DBS on to NUPDRS3 exam: not reported. hours from DBS off to NUPDRS3 exam: not reported. Parkinson medication: 1.0. deep brain stimulation symptoms: 0.0. order of OFF/ON Part III exams: not reported. OFF exam performed: not reported. reason OFF exam not performed: not reported. DBSOFFYN: not reported. time DBS switched off: not reported. ON exam performed: 1.0. reason ON exam not performed: not reported. HIFUYN: 0.0. DBSONYN: not reported. time DBS switched on: not reported. speech impairment: 1.0. reduced facial expression: 1.0. neck rigidity: 2.0. right arm rigidity: 2.0. left arm rigidity: 1.0. right leg rigidity: 1.0. left leg rigidity: 0.0. right foot tapping: 1.0. left foot tapping: 1.0. right hand movement: 2.0. left hand movement: 2.0. right hand postural tremor: 1.0. left hand postural tremor: 1.0. right hand tapping: 1.0. left hand tapping: 1.0. right leg agility: 1.0. left leg agility: 1.0. difficulty rising from chair: 0.0. gait impairment: 1.0. freezing of gait: 0.0. postural instability: 0.0. posture: 2.0. bradykinesia: 1.0. right hand resting tremor: 0.0. left hand resting tremor: 0.0. right hand kinesia: 1.0. left hand kinesia: 0.0. right arm action tremor: 0.0. left arm action tremor: 0.0. right leg action tremor: 0.0. left leg action tremor: 0.0. left leg action tremor: 0.0. tremor constancy: 0.0. MDS-UPDRS III total score: 25.0. dyskinesia presence: 1.0. DYSKIRAT: 0.0. numeric Hoehn & Yahr stage: 2.0. SEX: 0. AGE_AT_VISIT: 63.9. COHORT_DEFINITION: Parkinson's Disease. dyskinesia scale: 8.0. patient group: 1. prompts_400: paciente con Parkinson:. PATNO: 3003. EVENT_ID: V21. tratamiento recibido: 1.0. estado funcional actual: 1.0. horas entre la última dosis de medicación para EP y el examen NUPDRS3: 1.25. horas entre el encendido del DBS y el examen NUPDRS3: no informado. horas entre el apagado del DBS y el examen NUPDRS3: no informado. medicación para la EP: 1.0. síntomas de estimulación cerebral: 0.0. primer examen de la Parte III OFF o ON: no informado. examen OFF realizado: no informado. motivo no realizado examen OFF: no informado. DBSOFFYN: no informado. tiempo de suspensión del tratamiento DBS: no informado. examen ON realizado: 1.0. motivo no realizado examen ON: no informado. HIFUYN: 0.0. DBSONYN: no informado. tiempo de inicio del tratamiento DBS: no informado. alteración del habla: 1.0. expresión facial reducida: 1.0. rigidez cuello: 2.0. rigidez brazo derecho: 2.0. rigidez brazo izquierdo: 1.0. rigidez pierna derecha: 1.0. rigidez pierna izquierda: 0.0. tapping pie derecho: 1.0. tapping pie izquierdo: 1.0. movimiento mano derecha: 2.0. movimiento mano izquierda: 2.0. temblor postural mano derecha: 1.0. temblor postural mano izquierda: 1.0. tapping mano derecha: 1.0. tapping mano izquierda: 1.0. agilidad pierna derecha: 1.0. agilidad pierna izquierda: 1.0. dificultad para levantarse: 0.0. alteración de la marcha: 1.0. freezing de la marcha: 0.0. inestabilidad postural: 0.0. postura: 2.0. bradicinesia: 1.0. temblor de reposo mano derecha: 0.0. temblor de reposo mano izquierda: 0.0. kinésia mano derecha: 1.0. kinésia mano izquierda: 0.0. temblor de acción brazo derecho: 0.0. temblor de acción brazo izquierdo: 0.0. temblor de acción pierna derecha: 0.0. temblor de acción pierna izquierda: 0.0. temblor de acción pierna izquierda: 0.0. constancia del temblor: 0.0. puntuación total MDS-UPDRS III: 25.0. presencia de discinesias: 1.0. DYSKIRAT: 0.0. estadio Hoehn & Yahr numérico: 2.0. SEX: 0. AGE_AT_VISIT: 63.9. COHORT_DEFINITION: Parkinson's Disease. escala de discinesias: 8.0. grupo del paciente: 1

# %%
# CSV en español
df_parkinson[['PATNO', 'grupo', 'prompts_400']].to_csv(
    "/content/drive/MyDrive/avances/embebidos/prompts_400_es.csv",
    index=False,
    encoding='utf-8'
)

# CSV en inglés
df_parkinson[['PATNO', 'grupo', 'prompts_400_ing']].to_csv(
    "/content/drive/MyDrive/avances/embebidos/prompts_400_ing.csv",
    index=False,
    encoding='utf-8'
)

print("Archivos prompts_400_es.csv y prompts_400_ing.csv guardados correctamente.")
# Out:
# Archivos prompts_400_es.csv y prompts_400_ing.csv guardados correctamente.

# %% [markdown]
# # ELIMINAR TABLAS POR ESCALA

# %%
import pandas as pd
import os

# =========================
# 2) Rutas
# =========================
csv_path = "/content/drive/MyDrive/avances/cvs/originales/MDS-UPDRS_Part_III_28Oct2025_estandarizado_pd_mbrs (1).csv"
out_dir  = "/content/drive/MyDrive/avances/cvs/originales/"

# =========================
# 3) Cargar CSV
# =========================
# Si tu CSV usa punto y coma (;), cambia a: pd.read_csv(csv_path, sep=";")
df = pd.read_csv(csv_path)

print("Columnas originales:", len(df.columns))

# =========================
# 4) Version 1: sin MBRS + ciertas columnas
# =========================
cols_sinMBRS = [
    "NP3FTAPL", "NP3FTAPR", "NP3PRSPL", "NP3PRSPR", "NP3HMOVL", "NP3HMOVR", "MBRS"
]

df_sinMBRS = df.drop(columns=cols_sinMBRS, errors="ignore")
out1 = os.path.join(out_dir, "datos_sinMBRS.csv")
df_sinMBRS.to_csv(out1, index=False)
print("Guardado:", out1, "| Columnas:", len(df_sinMBRS.columns))

# =========================
# 5) Version 2: sin UPDRS (lista larga)
# =========================
cols_sinUPDRS = [
    "NP3SPCH","NP3FACXP","NP3RIGN","NP3RIGRU","NP3RIGLU","NP3RIGRL","NP3RIGLL",
    "NP3FTAPR","NP3FTAPL","NP3HMOVR","NP3HMOVL","NP3PRSPR","NP3PRSPL","NP3TTAPR",
    "NP3TTAPL","NP3LGAGR","NP3LGAGL","NP3RISNG","NP3GAIT","NP3FRZGT","NP3PSTBL",
    "NP3POSTR","NP3BRADY","NP3PTRMR","NP3PTRML","NP3KTRMR","NP3KTRML","NP3RTARU",
    "NP3RTALU","NP3RTARL","NP3RTALL","NP3RTALJ","NP3RTCON","NP3TOT"
]

df_sinUPDRS = df.drop(columns=cols_sinUPDRS, errors="ignore")
out2 = os.path.join(out_dir, "datos_sinUPDRS.csv")
df_sinUPDRS.to_csv(out2, index=False)
print("Guardado:", out2, "| Columnas:", len(df_sinUPDRS.columns))

# =========================
# 6) Version 3: sin H & Y Stage
# =========================
# (agrego variantes por si el nombre viene sin espacios)
cols_sinHY = ["H & Y Stage","NHY"]

df_sinHY = df.drop(columns=cols_sinHY, errors="ignore")
out3 = os.path.join(out_dir, "datos_sinH&Y.csv")
df_sinHY.to_csv(out3, index=False)
print("Guardado:", out3, "| Columnas:", len(df_sinHY.columns))

print("\n✅ Listo. Archivos generados en:", out_dir)
# Out:
# Columnas originales: 60
# Guardado: /content/drive/MyDrive/avances/cvs/originales/datos_sinMBRS.csv | Columnas: 53
# Guardado: /content/drive/MyDrive/avances/cvs/originales/datos_sinUPDRS.csv | Columnas: 26
# Guardado: /content/drive/MyDrive/avances/cvs/originales/datos_sinH&Y.csv | Columnas: 59
#
# ✅ Listo. Archivos generados en: /content/drive/MyDrive/avances/cvs/originales/

# %% [markdown]
# # PROMPTS POR ESCALA

# %%
from google.colab import drive
drive.mount("/content/drive")

import pandas as pd
import os

# =========================
# 1) Rutas
# =========================
csv_path = "/content/drive/MyDrive/avances/cvs/originales/MDS-UPDRS_Part_III_28Oct2025_estandarizado_pd_mbrs (1).csv"

out_emb = "/content/drive/MyDrive/avances/embebidos/"
os.makedirs(out_emb, exist_ok=True)

# =========================
# 2) Cargar dataset original
# =========================
df_original = pd.read_csv(csv_path)
df_original = pd.DataFrame(df_original)

# Agregar columna grupo=1
df_original["grupo"] = 1

# =========================
# 3) Columnas a eliminar (3 versiones)
# =========================
cols_sinMBRS = [
    "NP3FTAPL", "NP3FTAPR", "NP3PRSPL", "NP3PRSPR", "NP3HMOVL", "NP3HMOVR", "MBRS"
]

cols_sinUPDRS = [
    "NP3SPCH","NP3FACXP","NP3RIGN","NP3RIGRU","NP3RIGLU","NP3RIGRL","NP3RIGLL",
    "NP3FTAPR","NP3FTAPL","NP3HMOVR","NP3HMOVL","NP3PRSPR","NP3PRSPL","NP3TTAPR",
    "NP3TTAPL","NP3LGAGR","NP3LGAGL","NP3RISNG","NP3GAIT","NP3FRZGT","NP3PSTBL",
    "NP3POSTR","NP3BRADY","NP3PTRMR","NP3PTRML","NP3KTRMR","NP3KTRML","NP3RTARU",
    "NP3RTALU","NP3RTARL","NP3RTALL","NP3RTALJ","NP3RTCON","NP3TOT"
]

cols_sinHY = ["H & Y Stage", "H&Y Stage", "H & Y", "HY Stage"]

# =========================
# 4) Diccionario SOLO en inglés
# =========================
descripciones_en = {
    'Edad': 'age', 'Genero': 'gender', 'NP3BRADY': 'bradykinesia',
    'NP3FACXP': 'reduced facial expression', 'NP3FRZGT': 'freezing of gait',
    'NP3FTAPL': 'left foot tapping', 'NP3FTAPR': 'right foot tapping',
    'NP3GAIT': 'gait impairment', 'NP3HMOVL': 'left hand movement',
    'NP3HMOVR': 'right hand movement', 'NP3KTRML': 'left hand kinesia',
    'NP3KTRMR': 'right hand kinesia', 'NP3LGAGL': 'left leg agility',
    'NP3LGAGR': 'right leg agility', 'NP3POSTR': 'posture',
    'NP3PRSPL': 'left hand postural tremor', 'NP3PRSPR': 'right hand postural tremor',
    'NP3PSTBL': 'postural instability', 'NP3PTRML': 'left hand resting tremor',
    'NP3PTRMR': 'right hand resting tremor', 'NP3RIGLL': 'left leg rigidity',
    'NP3RIGLU': 'left arm rigidity', 'NP3RIGN': 'neck rigidity',
    'NP3RIGRL': 'right leg rigidity', 'NP3RIGRU': 'right arm rigidity',
    'NP3RISNG': 'difficulty rising from chair', 'NP3RTALJ': 'left leg action tremor',
    'NP3RTALL': 'left leg action tremor', 'NP3RTALU': 'left arm action tremor',
    'NP3RTARL': 'right leg action tremor', 'NP3RTARU': 'right arm action tremor',
    'NP3RTCON': 'tremor constancy', 'NP3SPCH': 'speech impairment',
    'NP3TOT': 'MDS-UPDRS III total score', 'NP3TTAPL': 'left hand tapping',
    'NP3TTAPR': 'right hand tapping', 'DBSYN': 'deep brain stimulation symptoms',
    'DYSKPRES': 'dyskinesia presence', 'MBRS': 'dyskinesia scale',
    'H & Y Stage': 'Hoehn & Yahr stage', 'NHY': 'numeric Hoehn & Yahr stage',
    'DBSOFFTM': 'time DBS switched off', 'DBSONTM': 'time DBS switched on',
    'HRDBSOFF': 'hours from DBS off to NUPDRS3 exam',
    'HRDBSON': 'hours from DBS on to NUPDRS3 exam',
    'HRPOSTMED': 'hours from last PD medication to NUPDRS3 exam',
    'OFFEXAM': 'OFF exam performed', 'OFFNORSN': 'reason OFF exam not performed',
    'ONEXAM': 'ON exam performed', 'ONNORSN': 'reason ON exam not performed',
    'ONOFFORDER': 'order of OFF/ON Part III exams', 'PDMEDYN': 'Parkinson medication',
    'PDSTATE': 'current functional state', 'PDTRTMNT': 'treatment received',
    'Pat_id': 'patient ID', 'PATNO': 'patient ID', 'grupo': 'patient group'
}

# =========================
# 5) Función para crear prompts SOLO EN INGLÉS
# =========================
def crear_prompts_parkinson_en(df, descripciones):
    prompts = []
    for _, row in df.iterrows():
        tipo_paciente = "Parkinson's patient" if row["grupo"] == 1 else "control subject"
        prompt_parts = [f"{tipo_paciente}:"]

        for col in df.columns:
            valor = row[col]

            if pd.isna(valor):
                valor = "not reported"
            else:
                if col == "Genero":
                    # (asumiendo 1=male, 0=female)
                    valor = "male" if valor == 1 else "female"

            desc = descripciones.get(col, col)
            prompt_parts.append(f"{desc}: {valor}")

        prompts.append(". ".join(prompt_parts))
    return prompts

# =========================
# 6) Helper para elegir columna ID
# =========================
def detectar_col_id(df):
    for c in ["PATNO", "Pat_id"]:
        if c in df.columns:
            return c
    return None

# =========================
# 7) Crear 3 datasets + prompts en inglés + guardar
# =========================
versiones = {
    "sinMBRS": df_original.drop(columns=cols_sinMBRS, errors="ignore").copy(),
    "sinUPDRS": df_original.drop(columns=cols_sinUPDRS, errors="ignore").copy(),
    "sinH&Y": df_original.drop(columns=cols_sinHY, errors="ignore").copy(),
}

for nombre_version, df_v in versiones.items():
    # crear columna de prompts solo inglés
    df_v["prompts_400_ing"] = crear_prompts_parkinson_en(df_v, descripciones_en)

    # escoger columna id si existe
    col_id = detectar_col_id(df_v)

    # guardar SOLO [ID, grupo, prompt]
    if col_id is not None:
        df_out = df_v[[col_id, "grupo", "prompts_400_ing"]]
    else:
        df_out = df_v[["grupo", "prompts_400_ing"]]

    out_path = os.path.join(out_emb, f"prompts_400_{nombre_version}_ing.csv")
    df_out.to_csv(out_path, index=False, encoding="utf-8")

    print(f"\n✅ Guardado: {out_path}")
    print("Ejemplo (primer prompt):")
    print(df_v["prompts_400_ing"].iloc[0])

print("\n✅ Listo: se generaron los 3 CSV de prompts SOLO EN INGLÉS.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ✅ Guardado: /content/drive/MyDrive/avances/embebidos/prompts_400_sinMBRS_ing.csv
# Ejemplo (primer prompt):
# Parkinson's patient:. patient ID: 3001. EVENT_ID: V17. treatment received: 1.0. current functional state: 1.0. hours from last PD medication to NUPDRS3 exam: 1.0. hours from DBS on to NUPDRS3 exam: not reported. hours from DBS off to NUPDRS3 exam: not reported. Parkinson medication: 1.0. deep brain stimulation symptoms: 0.0. order of OFF/ON Part III exams: 1.0. OFF exam performed: not reported. reason OFF exam not performed: not reported. DBSOFFYN: not reported. time DBS switched off: not reported. ON exam performed: 1.0. reason ON exam not performed: not reported. HIFUYN: not reported. DBSONYN: not reported. time DBS switched on: not reported. speech impairment: 2.0. reduced facial expression: 1.0. neck rigidity: 3.0. right arm rigidity: 1.0. left arm rigidity: 2.0. right leg rigidity: 1.0. left leg rigidity: 2.0. right hand tapping: 1.0. left hand tapping: 1.0. right leg agility: 2.0. left leg agility: 1.0. difficulty rising from chair: 0.0. gait impairment: 1.0. freezing of gait: 0.0. postural instability: 0.0. posture: 3.0. bradykinesia: 1.0. right hand resting tremor: 1.0. left hand resting tremor: 1.0. right hand kinesia: 2.0. left hand kinesia: 1.0. right arm action tremor: 0.0. left arm action tremor: 0.0. right leg action tremor: 0.0. left leg action tremor: 0.0. left leg action tremor: 0.0. tremor constancy: 0.0. MDS-UPDRS III total score: 40.0. dyskinesia presence: 1.0. DYSKIRAT: 0.0. numeric Hoehn & Yahr stage: 2.0. SEX: 1. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. patient group: 1
#
# ✅ Guardado: /content/drive/MyDrive/avances/embebidos/prompts_400_sinUPDRS_ing.csv
# Ejemplo (primer prompt):
# Parkinson's patient:. patient ID: 3001. EVENT_ID: V17. treatment received: 1.0. current functional state: 1.0. hours from last PD medication to NUPDRS3 exam: 1.0. hours from DBS on to NUPDRS3 exam: not reported. hours from DBS off to NUPDRS3 exam: not reported. Parkinson medication: 1.0. deep brain stimulation symptoms: 0.0. order of OFF/ON Part III exams: 1.0. OFF exam performed: not reported. reason OFF exam not performed: not reported. DBSOFFYN: not reported. time DBS switched off: not reported. ON exam performed: 1.0. reason ON exam not performed: not reported. HIFUYN: not reported. DBSONYN: not reported. time DBS switched on: not reported. dyskinesia presence: 1.0. DYSKIRAT: 0.0. numeric Hoehn & Yahr stage: 2.0. SEX: 1. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. dyskinesia scale: 13.0. patient group: 1
#
# ✅ Guardado: /content/drive/MyDrive/avances/embebidos/prompts_400_sinH&Y_ing.csv
# Ejemplo (primer prompt):
# Parkinson's patient:. patient ID: 3001. EVENT_ID: V17. treatment received: 1.0. current functional state: 1.0. hours from last PD medication to NUPDRS3 exam: 1.0. hours from DBS on to NUPDRS3 exam: not reported. hours from DBS off to NUPDRS3 exam: not reported. Parkinson medication: 1.0. deep brain stimulation symptoms: 0.0. order of OFF/ON Part III exams: 1.0. OFF exam performed: not reported. reason OFF exam not performed: not reported. DBSOFFYN: not reported. time DBS switched off: not reported. ON exam performed: 1.0. reason ON exam not performed: not reported. HIFUYN: not reported. DBSONYN: not reported. time DBS switched on: not reported. speech impairment: 2.0. reduced facial expression: 1.0. neck rigidity: 3.0. right arm rigidity: 1.0. left arm rigidity: 2.0. right leg rigidity: 1.0. left leg rigidity: 2.0. right foot tapping: 3.0. left foot tapping: 2.0. right hand movement: 3.0. left hand movement: 2.0. right hand postural tremor: 2.0. left hand postural tremor: 1.0. right hand tapping: 1.0. left hand tapping: 1.0. right leg agility: 2.0. left leg agility: 1.0. difficulty rising from chair: 0.0. gait impairment: 1.0. freezing of gait: 0.0. postural instability: 0.0. posture: 3.0. bradykinesia: 1.0. right hand resting tremor: 1.0. left hand resting tremor: 1.0. right hand kinesia: 2.0. left hand kinesia: 1.0. right arm action tremor: 0.0. left arm action tremor: 0.0. right leg action tremor: 0.0. left leg action tremor: 0.0. left leg action tremor: 0.0. tremor constancy: 0.0. MDS-UPDRS III total score: 40.0. dyskinesia presence: 1.0. DYSKIRAT: 0.0. numeric Hoehn & Yahr stage: 2.0. SEX: 1. AGE_AT_VISIT: 82.7. COHORT_DEFINITION: Parkinson's Disease. dyskinesia scale: 13.0. patient group: 1
#
# ✅ Listo: se generaron los 3 CSV de prompts SOLO EN INGLÉS.

# %% [markdown]
# # ESPAÑOL

# %% [markdown]
# **CLINICAL-BERT**

# %%
# =========================================
# PD (grupo==1): Leve/Moderado/Grave con ClinicalBERT
# =========================================
# !pip install -q sentence-transformers scikit-learn pandas seaborn matplotlib transformers

import pandas as pd
import torch, seaborn as sns, matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sentence_transformers import SentenceTransformer, models

# Rutas
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts.csv"
ORIG    = "/content/drive/MyDrive/avances/cvs/clasificación con tab y simple/DATASET_COMPLETO_ESTANDARIZADO.csv"

# Datos
df_prompts  = pd.read_csv(PROMPTS)  # requiere Pat_id, prompt
df_original = pd.read_csv(ORIG)

df = df_prompts.merge(df_original[['Pat_id','MBRS']], on='Pat_id', how='left')
df = df[df['grupo'] == 1].copy()

def clase_pd(m):
    if pd.isna(m): return -1
    if m <= 5: return 1
    if 6 <= m <= 12: return 2
    if 13 <= m <= 24: return 3
    return -1

df['clase_gravedad'] = df['MBRS'].apply(clase_pd)
df = df[df['clase_gravedad'] != -1].copy()

# Partición (reusa tus IDs PD)
train_ids = ['3102','3107','3108','3111','3113','3120','3124','3128','3134','3167','3174','3178',
             '3307','3309','3311','3314','3321','3322','3323','3327','3328','3360','3364','3366',
             '3380','3383','3552','3557','3564','3575','3585','3586','3753','3760','3764','3771',
             '3780','3789','3800','3814','3822','3826','3830','3863','4005','4006','4019','4024',
             '4025','4026','4030','4034','4035','40533','4069','40781','4081','4082','4083','40916',
             '41486','41829','50028','51731']
test_ids  = ['3105','3127','3166','3179','3181','3354','3392','3556','3577','3815','3818','3832','3867','4001','4080','51632']

pd_ids = set(df['Pat_id'].astype(str))
train_ids = [i for i in train_ids if i in pd_ids]
test_ids  = [i for i in test_ids  if i in pd_ids]

df_train = df[df['Pat_id'].astype(str).isin(train_ids)].copy()
df_test  = df[df['Pat_id'].astype(str).isin(test_ids)].copy()
assert not df_train.empty and not df_test.empty, f"Partición vacía. train={len(df_train)} test={len(df_test)}"

# ------- Embeddings: ClinicalBERT -------
device = "cuda" if torch.cuda.is_available() else "cpu"
backbone = "emilyalsentzer/Bio_ClinicalBERT"  # ClinicalBERT base

wb = models.Transformer(backbone, max_seq_length=512)
pool = models.Pooling(
    wb.get_word_embedding_dimension(),
    pooling_mode_mean_tokens=True,          # mean pooling sobre tokens
    pooling_mode_cls_token=False,
    pooling_mode_max_tokens=False
)
embedder = SentenceTransformer(modules=[wb, pool], device=device)

X_train = embedder.encode(df_train['prompt'].tolist(),
                          batch_size=32, normalize_embeddings=True,
                          convert_to_numpy=True, show_progress_bar=True)
X_test  = embedder.encode(df_test['prompt'].tolist(),
                          batch_size=32, normalize_embeddings=True,
                          convert_to_numpy=True, show_progress_bar=True)

y_train = df_train['clase_gravedad'].values
y_test  = df_test['clase_gravedad'].values

# ------- Clasificador -------
clf = RandomForestClassifier(n_estimators=300, class_weight='balanced',
                             random_state=42, n_jobs=-1)
clf.fit(X_train, y_train)

# ------- Evaluación -------
y_pred = clf.predict(X_test)
print("=== Reporte (PD: Leve/Moderado/Grave con ClinicalBERT) ===")
print(classification_report(y_test, y_pred, labels=[1,2,3],
                            target_names=["Leve","Moderado","Grave"], digits=3))

cm = confusion_matrix(y_test, y_pred, labels=[1,2,3])
cm_df = pd.DataFrame(cm, index=["Leve","Moderado","Grave"], columns=["Leve","Moderado","Grave"])
print("\nMatriz de Confusión:"); print(cm_df)

plt.figure(figsize=(5.2,4.4))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
plt.ylabel("Real"); plt.xlabel("Predicha"); plt.title("Confusión – PD (ClinicalBERT)")
plt.tight_layout(); plt.show()

print(f"Train PD: {len(df_train)} | Test PD: {len(df_test)} | Device: {device}")
# Out:
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# === Reporte (PD: Leve/Moderado/Grave con ClinicalBERT) ===
#               precision    recall  f1-score   support
#
#         Leve      1.000     1.000     1.000         5
#     Moderado      1.000     0.778     0.875         9
#        Grave      0.500     1.000     0.667         2
#
#     accuracy                          0.875        16
#    macro avg      0.833     0.926     0.847        16
# weighted avg      0.938     0.875     0.888        16
#
#
# Matriz de Confusión:
#           Leve  Moderado  Grave
# Leve         5         0      0
# Moderado     0         7      2
# Grave        0         0      2
# Train PD: 64 | Test PD: 16 | Device: cpu

# %%
# ===== Guardar embebidos ClinicalBERT + metadatos =====
import os, re, numpy as np
import pandas as pd

BASE = "/content/drive/MyDrive/avances/embebidos"
tag  = re.sub(r"[^A-Za-z0-9]+", "_", backbone)  # p.ej. emilyalsentzer_Bio_ClinicalBERT
OUT  = f"{BASE}/{tag}"
os.makedirs(OUT, exist_ok=True)

# dim del embebido (768 en ClinicalBERT con mean pooling)
try:
    dim = embedder.get_sentence_embedding_dimension()
except Exception:
    dim = X_train.shape[1]

e_cols = [f"e_{i}" for i in range(dim)]

def pack(df_part, X_part, y_part, split_name):
    tmp = pd.DataFrame(X_part.astype("float32"), columns=e_cols)
    tmp["Pat_id"]         = df_part["Pat_id"].astype(str).values
    tmp["MBRS"]           = df_part["MBRS"].values
    tmp["clase_gravedad"] = y_part
    tmp["split"]          = split_name
    tmp["prompt"]         = df_part["prompt"].values
    tmp["model_name"]     = backbone
    return tmp

df_train_emb = pack(df_train, X_train, y_train, "train")
df_test_emb  = pack(df_test,  X_test,  y_test,  "test")
df_emb_cb    = pd.concat([df_train_emb, df_test_emb], ignore_index=True)

parquet_path = f"{OUT}/embeddings_pd_{tag}.parquet"
csv_path     = f"{OUT}/embeddings_pd_{tag}.csv"
npz_path     = f"{OUT}/embeddings_pd_arrays_{tag}.npz"

df_emb_cb.to_parquet(parquet_path, index=False)
df_emb_cb.to_csv(csv_path, index=False)
np.savez_compressed(
    npz_path,
    X_train=X_train, X_test=X_test,
    y_train=y_train, y_test=y_test,
    train_ids=df_train["Pat_id"].astype(str).values,
    test_ids=df_test["Pat_id"].astype(str).values,
    dim=dim, model_name=backbone
)

print("Guardado ClinicalBERT en:")
print(parquet_path)
print(csv_path)
print(npz_path)
# Out:
# Guardado ClinicalBERT en:
# /content/drive/MyDrive/avances/embebidos/emilyalsentzer_Bio_ClinicalBERT/embeddings_pd_emilyalsentzer_Bio_ClinicalBERT.parquet
# /content/drive/MyDrive/avances/embebidos/emilyalsentzer_Bio_ClinicalBERT/embeddings_pd_emilyalsentzer_Bio_ClinicalBERT.csv
# /content/drive/MyDrive/avances/embebidos/emilyalsentzer_Bio_ClinicalBERT/embeddings_pd_arrays_emilyalsentzer_Bio_ClinicalBERT.npz

# %% [markdown]
# # **INGLÉS**

# %% [markdown]
# **CLINICAL-BERT**

# %%
# =========================================
# PD fijo (train/test dados) + CV en train con ClinicalBERT
# =========================================
# !pip install -q sentence-transformers scikit-learn pandas seaborn matplotlib transformers

import numpy as np, pandas as pd, torch, matplotlib.pyplot as plt, seaborn as sns
from sentence_transformers import SentenceTransformer, models
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

# Rutas
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts_ing.csv"  # tiene Pat_id, prompt, grupo
ORIG    = "/content/drive/MyDrive/avances/cvs/clasificación con tab y simple/DATASET_COMPLETO_ESTANDARIZADO.csv"

# 1) Datos
dfp = pd.read_csv(PROMPTS)
dfo = pd.read_csv(ORIG)

# Une SOLO MBRS; grupo ya está en prompts
df = dfp.merge(dfo[['Pat_id','MBRS']], on='Pat_id', how='left')
df = df[df['grupo'] == 1].copy()  # solo Parkinson

def clase_pd(m):
    if pd.isna(m): return -1
    if m <= 5: return 1
    if 6 <= m <= 12: return 2
    if 13 <= m <= 24: return 3
    return -1

df['clase_gravedad'] = df['MBRS'].apply(clase_pd)
df = df[df['clase_gravedad'] != -1].copy()

# 2) Split fijo
test_ids  = ['3105','3127','3166','3179','3181','3354','3392','3556','3577','3815','3818','3832','3867','4001','4080','51632']
train_ids = ['3102','3107','3108','3111','3113','3120','3124','3128','3134','3167','3174','3178','3307','3309','3311','3314',
             '3321','3322','3323','3327','3328','3360','3364','3366','3380','3383','3552','3557','3564','3575','3585','3586',
             '3753','3760','3764','3771','3780','3789','3800','3814','3822','3826','3830','3863','4005','4006','4019','4024',
             '4025','4026','4030','4034','4035','40533','4069','40781','4081','4082','4083','40916','41486','41829','50028','51731']

pd_ids = set(df['Pat_id'].astype(str))
train_ids = [i for i in train_ids if i in pd_ids]
test_ids  = [i for i in test_ids  if i in pd_ids]

df_train = df[df['Pat_id'].astype(str).isin(train_ids)].copy()
df_test  = df[df['Pat_id'].astype(str).isin(test_ids)].copy()
assert not df_train.empty and not df_test.empty, f"Split vacío. train={len(df_train)} test={len(df_test)}"

# 3) Embeddings ClinicalBERT (mean pooling)
device   = "cuda" if torch.cuda.is_available() else "cpu"
backbone = "emilyalsentzer/Bio_ClinicalBERT"
wb = models.Transformer(backbone, max_seq_length=512)
pool = models.Pooling(wb.get_word_embedding_dimension(), pooling_mode_mean_tokens=True)
embedder = SentenceTransformer(modules=[wb, pool], device=device)

X_train = embedder.encode(df_train['prompt_en'].tolist(), batch_size=32, normalize_embeddings=True,
                          convert_to_numpy=True, show_progress_bar=True)
X_test  = embedder.encode(df_test['prompt_en'].tolist(),  batch_size=32, normalize_embeddings=True,
                          convert_to_numpy=True, show_progress_bar=True)
y_train = df_train['clase_gravedad'].values
y_test  = df_test['clase_gravedad'].values

# 4) CV en train (k-fold estratificado) para estimar media±std
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
accs, f1mac = [], []
for tr, va in skf.split(X_train, y_train):
    clf_cv = RandomForestClassifier(n_estimators=300, class_weight='balanced', random_state=42, n_jobs=-1)
    clf_cv.fit(X_train[tr], y_train[tr])
    yp = clf_cv.predict(X_train[va])
    accs.append(accuracy_score(y_train[va], yp))
    f1mac.append(f1_score(y_train[va], yp, average='macro'))

print(f"CV-5 | acc={np.mean(accs):.3f}±{np.std(accs):.3f}  f1_macro={np.mean(f1mac):.3f}±{np.std(f1mac):.3f}")

# 5) Entrena en TODO el train y evalúa en test fijo
clf = RandomForestClassifier(n_estimators=300, class_weight='balanced', random_state=42, n_jobs=-1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("\n=== Test fijo (PD: Leve/Moderado/Grave) ===")
print(classification_report(y_test, y_pred, labels=[1,2,3],
                            target_names=["Leve","Moderado","Grave"], digits=3))

cm = confusion_matrix(y_test, y_pred, labels=[1,2,3])
cm_df = pd.DataFrame(cm, index=["Leve","Moderado","Grave"], columns=["Leve","Moderado","Grave"])
print("\nMatriz de Confusión:"); print(cm_df)

plt.figure(figsize=(5.2,4.4))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
plt.ylabel("Real"); plt.xlabel("Predicha"); plt.title("Confusión – PD (ClinicalBERT, test fijo)")
plt.tight_layout(); plt.show()

print(f"Train PD: {len(df_train)} | Test PD: {len(df_test)} | Device: {device}")
# Out:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# CV-5 | acc=0.701±0.097  f1_macro=0.549±0.159
#
# === Test fijo (PD: Leve/Moderado/Grave) ===
#               precision    recall  f1-score   support
#
#         Leve      0.833     1.000     0.909         5
#     Moderado      1.000     0.778     0.875         9
#        Grave      0.667     1.000     0.800         2
#
#     accuracy                          0.875        16
#    macro avg      0.833     0.926     0.861        16
# weighted avg      0.906     0.875     0.876        16
#
#
# Matriz de Confusión:
#           Leve  Moderado  Grave
# Leve         5         0      0
# Moderado     1         7      1
# Grave        0         0      2
# Train PD: 64 | Test PD: 16 | Device: cpu

# %%
from sklearn.decomposition import PCA

# Reducir a 2 dimensiones usando PCA
pca = PCA(n_components=2)
X_train_reduced = pca.fit_transform(X_train)

# Graficar las muestras proyectadas en 2D
plt.figure(figsize=(8,6))
sns.scatterplot(x=X_train_reduced[:, 0], y=X_train_reduced[:, 1], hue=y_train, palette="viridis", alpha=0.7)
plt.title("Reducción de Dimensionalidad con PCA")
plt.xlabel("Componente 1")
plt.ylabel("Componente 2")
plt.show()

# %% [markdown]
# # CON PYTHORCH (Inglés)

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)

# %%
import os
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel

# Rutas
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts_400_ing.csv"  # columnas: PATNO, prompts_400_ing, grupo
OUT_DIR = "/content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd"

os.makedirs(OUT_DIR, exist_ok=True)

# 1. Cargar CSV
df = pd.read_csv(PROMPTS)
print(df.columns)  # para verificar que estén 'PATNO', 'prompts_400_ing', 'grupo'

# (Opcional) filtrar por grupo si quieres solo PD
# df = df[df["grupo"] == "PD"]

# 2. Cargar ClinicalBERT
MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)
model.to(device)
model.eval()

# 3. Función para obtener embeddings (CLS) de ClinicalBERT
def get_clinicalbert_embeddings(text_list, batch_size=16, max_length=128):
    """
    text_list: lista de strings (prompts)
    Devuelve: tensor [n_textos, dim] con el embedding CLS normalizado
    """
    all_embeddings = []

    with torch.no_grad():
        for i in range(0, len(text_list), batch_size):
            batch_texts = text_list[i:i + batch_size]

            encoded = tokenizer(
                batch_texts,
                padding=True,
                truncation=True,
                max_length=max_length,
                return_tensors="pt"
            )

            input_ids = encoded["input_ids"].to(device)
            attention_mask = encoded["attention_mask"].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            last_hidden_state = outputs.last_hidden_state  # [batch, seq_len, hidden_size]

            # Usamos el token [CLS]
            cls_embeddings = last_hidden_state[:, 0, :]  # [batch, hidden_size]

            # Normalizar cada vector
            cls_embeddings = cls_embeddings / cls_embeddings.norm(dim=-1, keepdim=True)

            all_embeddings.append(cls_embeddings.cpu())

    return torch.cat(all_embeddings, dim=0)  # [n_textos, dim]


# 4. Calcular embedding por paciente y guardar como .npy
for patno, sub_df in df.groupby("PATNO"):
    texts = sub_df["prompts_400_ing"].astype(str).tolist()

    if len(texts) == 0:
        continue

    # Embeddings de todos los prompts del paciente
    emb_prompts = get_clinicalbert_embeddings(texts, batch_size=16, max_length=128)  # [n_prompts_paciente, dim]

    # Promedio por paciente
    emb_patient = emb_prompts.mean(dim=0)  # [dim]
    emb_patient = emb_patient / emb_patient.norm()

    # Pasar a numpy
    emb_patient_np = emb_patient.numpy()  # shape (dim,)

    # Guardar cada paciente en un archivo .npy
    out_path = os.path.join(OUT_DIR, f"{patno}.npy")
    np.save(out_path, emb_patient_np)

    print(f"Guardado embedding .npy de paciente {patno} en {out_path}")
# Out:
# Index(['PATNO', 'grupo', 'prompts_400_ing'], dtype='object')
# Guardado embedding .npy de paciente 3001 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3001.npy
# Guardado embedding .npy de paciente 3002 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3002.npy
# Guardado embedding .npy de paciente 3003 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3003.npy
# Guardado embedding .npy de paciente 3005 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3005.npy
# Guardado embedding .npy de paciente 3006 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3006.npy
# Guardado embedding .npy de paciente 3007 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3007.npy
# Guardado embedding .npy de paciente 3010 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3010.npy
# Guardado embedding .npy de paciente 3012 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3012.npy
# Guardado embedding .npy de paciente 3014 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3014.npy
# Guardado embedding .npy de paciente 3018 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3018.npy
# Guardado embedding .npy de paciente 3020 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3020.npy
# Guardado embedding .npy de paciente 3021 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3021.npy
# Guardado embedding .npy de paciente 3023 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3023.npy
# Guardado embedding .npy de paciente 3024 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3024.npy
# Guardado embedding .npy de paciente 3025 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3025.npy
# Guardado embedding .npy de paciente 3026 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3026.npy
# Guardado embedding .npy de paciente 3027 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3027.npy
# Guardado embedding .npy de paciente 3028 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3028.npy
# Guardado embedding .npy de paciente 3051 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3051.npy
# Guardado embedding .npy de paciente 3052 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3052.npy
# Guardado embedding .npy de paciente 3054 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3054.npy
# Guardado embedding .npy de paciente 3056 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3056.npy
# Guardado embedding .npy de paciente 3058 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3058.npy
# Guardado embedding .npy de paciente 3059 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3059.npy
# Guardado embedding .npy de paciente 3060 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3060.npy
# Guardado embedding .npy de paciente 3061 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3061.npy
# Guardado embedding .npy de paciente 3062 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3062.npy
# Guardado embedding .npy de paciente 3066 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3066.npy
# Guardado embedding .npy de paciente 3067 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3067.npy
# Guardado embedding .npy de paciente 3068 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3068.npy
# Guardado embedding .npy de paciente 3076 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3076.npy
# Guardado embedding .npy de paciente 3077 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3077.npy
# Guardado embedding .npy de paciente 3078 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3078.npy
# Guardado embedding .npy de paciente 3080 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3080.npy
# Guardado embedding .npy de paciente 3081 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3081.npy
# Guardado embedding .npy de paciente 3083 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3083.npy
# Guardado embedding .npy de paciente 3086 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3086.npy
# Guardado embedding .npy de paciente 3088 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3088.npy
# Guardado embedding .npy de paciente 3089 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3089.npy
# Guardado embedding .npy de paciente 3102 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3102.npy
# Guardado embedding .npy de paciente 3105 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3105.npy
# Guardado embedding .npy de paciente 3107 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3107.npy
# Guardado embedding .npy de paciente 3108 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3108.npy
# Guardado embedding .npy de paciente 3110 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3110.npy
# Guardado embedding .npy de paciente 3111 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3111.npy
# Guardado embedding .npy de paciente 3113 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3113.npy
# Guardado embedding .npy de paciente 3116 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3116.npy
# Guardado embedding .npy de paciente 3118 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3118.npy
# Guardado embedding .npy de paciente 3119 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3119.npy
# Guardado embedding .npy de paciente 3120 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3120.npy
# Guardado embedding .npy de paciente 3122 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3122.npy
# Guardado embedding .npy de paciente 3123 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3123.npy
# Guardado embedding .npy de paciente 3124 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3124.npy
# Guardado embedding .npy de paciente 3125 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3125.npy
# Guardado embedding .npy de paciente 3126 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3126.npy
# Guardado embedding .npy de paciente 3127 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3127.npy
# Guardado embedding .npy de paciente 3128 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3128.npy
# Guardado embedding .npy de paciente 3129 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3129.npy
# Guardado embedding .npy de paciente 3130 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3130.npy
# Guardado embedding .npy de paciente 3131 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3131.npy
# Guardado embedding .npy de paciente 3132 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3132.npy
# Guardado embedding .npy de paciente 3133 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3133.npy
# Guardado embedding .npy de paciente 3134 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3134.npy
# Guardado embedding .npy de paciente 3150 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3150.npy
# Guardado embedding .npy de paciente 3154 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3154.npy
# Guardado embedding .npy de paciente 3162 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3162.npy
# Guardado embedding .npy de paciente 3164 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3164.npy
# Guardado embedding .npy de paciente 3166 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3166.npy
# Guardado embedding .npy de paciente 3167 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3167.npy
# Guardado embedding .npy de paciente 3168 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3168.npy
# Guardado embedding .npy de paciente 3173 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3173.npy
# Guardado embedding .npy de paciente 3174 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3174.npy
# Guardado embedding .npy de paciente 3175 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3175.npy
# Guardado embedding .npy de paciente 3176 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3176.npy
# Guardado embedding .npy de paciente 3177 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3177.npy
# Guardado embedding .npy de paciente 3178 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3178.npy
# Guardado embedding .npy de paciente 3179 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3179.npy
# Guardado embedding .npy de paciente 3180 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3180.npy
# Guardado embedding .npy de paciente 3181 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3181.npy
# Guardado embedding .npy de paciente 3182 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3182.npy
# Guardado embedding .npy de paciente 3184 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3184.npy
# Guardado embedding .npy de paciente 3185 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3185.npy
# Guardado embedding .npy de paciente 3186 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3186.npy
# Guardado embedding .npy de paciente 3187 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3187.npy
# Guardado embedding .npy de paciente 3190 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3190.npy
# Guardado embedding .npy de paciente 3203 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3203.npy
# Guardado embedding .npy de paciente 3205 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3205.npy
# Guardado embedding .npy de paciente 3207 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3207.npy
# Guardado embedding .npy de paciente 3209 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3209.npy
# Guardado embedding .npy de paciente 3210 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3210.npy
# Guardado embedding .npy de paciente 3211 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3211.npy
# Guardado embedding .npy de paciente 3212 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3212.npy
# Guardado embedding .npy de paciente 3214 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3214.npy
# Guardado embedding .npy de paciente 3218 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3218.npy
# Guardado embedding .npy de paciente 3220 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3220.npy
# Guardado embedding .npy de paciente 3223 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3223.npy
# Guardado embedding .npy de paciente 3224 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3224.npy
# Guardado embedding .npy de paciente 3225 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3225.npy
# Guardado embedding .npy de paciente 3226 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3226.npy
# Guardado embedding .npy de paciente 3227 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3227.npy
# Guardado embedding .npy de paciente 3228 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3228.npy
# Guardado embedding .npy de paciente 3229 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3229.npy
# Guardado embedding .npy de paciente 3230 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3230.npy
# Guardado embedding .npy de paciente 3231 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3231.npy
# Guardado embedding .npy de paciente 3232 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3232.npy
# Guardado embedding .npy de paciente 3233 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3233.npy
# Guardado embedding .npy de paciente 3234 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3234.npy
# Guardado embedding .npy de paciente 3236 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3236.npy
# Guardado embedding .npy de paciente 3251 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3251.npy
# Guardado embedding .npy de paciente 3252 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3252.npy
# Guardado embedding .npy de paciente 3253 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3253.npy
# Guardado embedding .npy de paciente 3254 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3254.npy
# Guardado embedding .npy de paciente 3263 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3263.npy
# Guardado embedding .npy de paciente 3265 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3265.npy
# Guardado embedding .npy de paciente 3267 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3267.npy
# Guardado embedding .npy de paciente 3268 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3268.npy
# Guardado embedding .npy de paciente 3269 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3269.npy
# Guardado embedding .npy de paciente 3272 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3272.npy
# Guardado embedding .npy de paciente 3275 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3275.npy
# Guardado embedding .npy de paciente 3278 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3278.npy
# Guardado embedding .npy de paciente 3279 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3279.npy
# Guardado embedding .npy de paciente 3280 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3280.npy
# Guardado embedding .npy de paciente 3281 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3281.npy
# Guardado embedding .npy de paciente 3282 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3282.npy
# Guardado embedding .npy de paciente 3284 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3284.npy
# Guardado embedding .npy de paciente 3285 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3285.npy
# Guardado embedding .npy de paciente 3288 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3288.npy
# Guardado embedding .npy de paciente 3289 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3289.npy
# Guardado embedding .npy de paciente 3290 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3290.npy
# Guardado embedding .npy de paciente 3305 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3305.npy
# Guardado embedding .npy de paciente 3307 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3307.npy
# Guardado embedding .npy de paciente 3308 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3308.npy
# Guardado embedding .npy de paciente 3309 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3309.npy
# Guardado embedding .npy de paciente 3311 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3311.npy
# Guardado embedding .npy de paciente 3312 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3312.npy
# Guardado embedding .npy de paciente 3313 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3313.npy
# Guardado embedding .npy de paciente 3314 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3314.npy
# Guardado embedding .npy de paciente 3321 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3321.npy
# Guardado embedding .npy de paciente 3322 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3322.npy
# Guardado embedding .npy de paciente 3323 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3323.npy
# Guardado embedding .npy de paciente 3325 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3325.npy
# Guardado embedding .npy de paciente 3327 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3327.npy
# Guardado embedding .npy de paciente 3328 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3328.npy
# Guardado embedding .npy de paciente 3329 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3329.npy
# Guardado embedding .npy de paciente 3330 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3330.npy
# Guardado embedding .npy de paciente 3331 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3331.npy
# Guardado embedding .npy de paciente 3332 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3332.npy
# Guardado embedding .npy de paciente 3333 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3333.npy
# Guardado embedding .npy de paciente 3352 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3352.npy
# Guardado embedding .npy de paciente 3354 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3354.npy
# Guardado embedding .npy de paciente 3359 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3359.npy
# Guardado embedding .npy de paciente 3360 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3360.npy
# Guardado embedding .npy de paciente 3364 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3364.npy
# Guardado embedding .npy de paciente 3365 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3365.npy
# Guardado embedding .npy de paciente 3366 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3366.npy
# Guardado embedding .npy de paciente 3367 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3367.npy
# Guardado embedding .npy de paciente 3371 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3371.npy
# Guardado embedding .npy de paciente 3372 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3372.npy
# Guardado embedding .npy de paciente 3373 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3373.npy
# Guardado embedding .npy de paciente 3374 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3374.npy
# Guardado embedding .npy de paciente 3375 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3375.npy
# Guardado embedding .npy de paciente 3376 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3376.npy
# Guardado embedding .npy de paciente 3377 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3377.npy
# Guardado embedding .npy de paciente 3378 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3378.npy
# Guardado embedding .npy de paciente 3380 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3380.npy
# Guardado embedding .npy de paciente 3383 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3383.npy
# Guardado embedding .npy de paciente 3385 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3385.npy
# Guardado embedding .npy de paciente 3386 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3386.npy
# Guardado embedding .npy de paciente 3387 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3387.npy
# Guardado embedding .npy de paciente 3392 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3392.npy
# Guardado embedding .npy de paciente 3400 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3400.npy
# Guardado embedding .npy de paciente 3403 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3403.npy
# Guardado embedding .npy de paciente 3406 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3406.npy
# Guardado embedding .npy de paciente 3407 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3407.npy
# Guardado embedding .npy de paciente 3409 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3409.npy
# Guardado embedding .npy de paciente 3413 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3413.npy
# Guardado embedding .npy de paciente 3415 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3415.npy
# Guardado embedding .npy de paciente 3416 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3416.npy
# Guardado embedding .npy de paciente 3417 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3417.npy
# Guardado embedding .npy de paciente 3418 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3418.npy
# Guardado embedding .npy de paciente 3419 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3419.npy
# Guardado embedding .npy de paciente 3420 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3420.npy
# Guardado embedding .npy de paciente 3421 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3421.npy
# Guardado embedding .npy de paciente 3422 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3422.npy
# Guardado embedding .npy de paciente 3423 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3423.npy
# Guardado embedding .npy de paciente 3429 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3429.npy
# Guardado embedding .npy de paciente 3430 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3430.npy
# Guardado embedding .npy de paciente 3431 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3431.npy
# Guardado embedding .npy de paciente 3432 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3432.npy
# Guardado embedding .npy de paciente 3433 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3433.npy
# Guardado embedding .npy de paciente 3434 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3434.npy
# Guardado embedding .npy de paciente 3435 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3435.npy
# Guardado embedding .npy de paciente 3436 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3436.npy
# Guardado embedding .npy de paciente 3439 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3439.npy
# Guardado embedding .npy de paciente 3440 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3440.npy
# Guardado embedding .npy de paciente 3442 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3442.npy
# Guardado embedding .npy de paciente 3443 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3443.npy
# Guardado embedding .npy de paciente 3444 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3444.npy
# Guardado embedding .npy de paciente 3445 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3445.npy
# Guardado embedding .npy de paciente 3446 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3446.npy
# Guardado embedding .npy de paciente 3447 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3447.npy
# Guardado embedding .npy de paciente 3448 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3448.npy
# Guardado embedding .npy de paciente 3451 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3451.npy
# Guardado embedding .npy de paciente 3454 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3454.npy
# Guardado embedding .npy de paciente 3455 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3455.npy
# Guardado embedding .npy de paciente 3459 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3459.npy
# Guardado embedding .npy de paciente 3461 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3461.npy
# Guardado embedding .npy de paciente 3462 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3462.npy
# Guardado embedding .npy de paciente 3467 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3467.npy
# Guardado embedding .npy de paciente 3469 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3469.npy
# Guardado embedding .npy de paciente 3470 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3470.npy
# Guardado embedding .npy de paciente 3471 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3471.npy
# Guardado embedding .npy de paciente 3472 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3472.npy
# Guardado embedding .npy de paciente 3473 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3473.npy
# Guardado embedding .npy de paciente 3474 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3474.npy
# Guardado embedding .npy de paciente 3475 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3475.npy
# Guardado embedding .npy de paciente 3476 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3476.npy
# Guardado embedding .npy de paciente 3482 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3482.npy
# Guardado embedding .npy de paciente 3500 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3500.npy
# Guardado embedding .npy de paciente 3501 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3501.npy
# Guardado embedding .npy de paciente 3502 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3502.npy
# Guardado embedding .npy de paciente 3504 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3504.npy
# Guardado embedding .npy de paciente 3505 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3505.npy
# Guardado embedding .npy de paciente 3506 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3506.npy
# Guardado embedding .npy de paciente 3507 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3507.npy
# Guardado embedding .npy de paciente 3509 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3509.npy
# Guardado embedding .npy de paciente 3510 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3510.npy
# Guardado embedding .npy de paciente 3513 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3513.npy
# Guardado embedding .npy de paciente 3514 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3514.npy
# Guardado embedding .npy de paciente 3516 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3516.npy
# Guardado embedding .npy de paciente 3522 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3522.npy
# Guardado embedding .npy de paciente 3528 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3528.npy
# Guardado embedding .npy de paciente 3530 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3530.npy
# Guardado embedding .npy de paciente 3532 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3532.npy
# Guardado embedding .npy de paciente 3533 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3533.npy
# Guardado embedding .npy de paciente 3534 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3534.npy
# Guardado embedding .npy de paciente 3535 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3535.npy
# Guardado embedding .npy de paciente 3536 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3536.npy
# Guardado embedding .npy de paciente 3540 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3540.npy
# Guardado embedding .npy de paciente 3542 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3542.npy
# Guardado embedding .npy de paciente 3552 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3552.npy
# Guardado embedding .npy de paciente 3556 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3556.npy
# Guardado embedding .npy de paciente 3557 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3557.npy
# Guardado embedding .npy de paciente 3558 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3558.npy
# Guardado embedding .npy de paciente 3559 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3559.npy
# Guardado embedding .npy de paciente 3561 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3561.npy
# Guardado embedding .npy de paciente 3562 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3562.npy
# Guardado embedding .npy de paciente 3564 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3564.npy
# Guardado embedding .npy de paciente 3567 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3567.npy
# Guardado embedding .npy de paciente 3574 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3574.npy
# Guardado embedding .npy de paciente 3575 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3575.npy
# Guardado embedding .npy de paciente 3577 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3577.npy
# Guardado embedding .npy de paciente 3584 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3584.npy
# Guardado embedding .npy de paciente 3585 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3585.npy
# Guardado embedding .npy de paciente 3586 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3586.npy
# Guardado embedding .npy de paciente 3587 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3587.npy
# Guardado embedding .npy de paciente 3588 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3588.npy
# Guardado embedding .npy de paciente 3589 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3589.npy
# Guardado embedding .npy de paciente 3591 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3591.npy
# Guardado embedding .npy de paciente 3592 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3592.npy
# Guardado embedding .npy de paciente 3593 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3593.npy
# Guardado embedding .npy de paciente 3601 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3601.npy
# Guardado embedding .npy de paciente 3603 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3603.npy
# Guardado embedding .npy de paciente 3604 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3604.npy
# Guardado embedding .npy de paciente 3605 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3605.npy
# Guardado embedding .npy de paciente 3606 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3606.npy
# Guardado embedding .npy de paciente 3607 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3607.npy
# Guardado embedding .npy de paciente 3608 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3608.npy
# Guardado embedding .npy de paciente 3609 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3609.npy
# Guardado embedding .npy de paciente 3612 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3612.npy
# Guardado embedding .npy de paciente 3616 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3616.npy
# Guardado embedding .npy de paciente 3617 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3617.npy
# Guardado embedding .npy de paciente 3618 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3618.npy
# Guardado embedding .npy de paciente 3621 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3621.npy
# Guardado embedding .npy de paciente 3622 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3622.npy
# Guardado embedding .npy de paciente 3623 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3623.npy
# Guardado embedding .npy de paciente 3625 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3625.npy
# Guardado embedding .npy de paciente 3626 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3626.npy
# Guardado embedding .npy de paciente 3628 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3628.npy
# Guardado embedding .npy de paciente 3629 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3629.npy
# Guardado embedding .npy de paciente 3630 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3630.npy
# Guardado embedding .npy de paciente 3631 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3631.npy
# Guardado embedding .npy de paciente 3632 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3632.npy
# Guardado embedding .npy de paciente 3633 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3633.npy
# Guardado embedding .npy de paciente 3634 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3634.npy
# Guardado embedding .npy de paciente 3638 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3638.npy
# Guardado embedding .npy de paciente 3650 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3650.npy
# Guardado embedding .npy de paciente 3652 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3652.npy
# Guardado embedding .npy de paciente 3653 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3653.npy
# Guardado embedding .npy de paciente 3654 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3654.npy
# Guardado embedding .npy de paciente 3657 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3657.npy
# Guardado embedding .npy de paciente 3659 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3659.npy
# Guardado embedding .npy de paciente 3660 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3660.npy
# Guardado embedding .npy de paciente 3661 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3661.npy
# Guardado embedding .npy de paciente 3663 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3663.npy
# Guardado embedding .npy de paciente 3664 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3664.npy
# Guardado embedding .npy de paciente 3665 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3665.npy
# Guardado embedding .npy de paciente 3666 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3666.npy
# Guardado embedding .npy de paciente 3700 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3700.npy
# Guardado embedding .npy de paciente 3701 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3701.npy
# Guardado embedding .npy de paciente 3702 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3702.npy
# Guardado embedding .npy de paciente 3703 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3703.npy
# Guardado embedding .npy de paciente 3704 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3704.npy
# Guardado embedding .npy de paciente 3705 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3705.npy
# Guardado embedding .npy de paciente 3706 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3706.npy
# Guardado embedding .npy de paciente 3707 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3707.npy
# Guardado embedding .npy de paciente 3708 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3708.npy
# Guardado embedding .npy de paciente 3709 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3709.npy
# Guardado embedding .npy de paciente 3710 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3710.npy
# Guardado embedding .npy de paciente 3711 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3711.npy
# Guardado embedding .npy de paciente 3752 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3752.npy
# Guardado embedding .npy de paciente 3753 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3753.npy
# Guardado embedding .npy de paciente 3757 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3757.npy
# Guardado embedding .npy de paciente 3758 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3758.npy
# Guardado embedding .npy de paciente 3760 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3760.npy
# Guardado embedding .npy de paciente 3762 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3762.npy
# Guardado embedding .npy de paciente 3763 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3763.npy
# Guardado embedding .npy de paciente 3764 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3764.npy
# Guardado embedding .npy de paciente 3766 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3766.npy
# Guardado embedding .npy de paciente 3770 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3770.npy
# Guardado embedding .npy de paciente 3771 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3771.npy
# Guardado embedding .npy de paciente 3773 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3773.npy
# Guardado embedding .npy de paciente 3774 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3774.npy
# Guardado embedding .npy de paciente 3775 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3775.npy
# Guardado embedding .npy de paciente 3776 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3776.npy
# Guardado embedding .npy de paciente 3777 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3777.npy
# Guardado embedding .npy de paciente 3778 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3778.npy
# Guardado embedding .npy de paciente 3780 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3780.npy
# Guardado embedding .npy de paciente 3781 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3781.npy
# Guardado embedding .npy de paciente 3785 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3785.npy
# Guardado embedding .npy de paciente 3787 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3787.npy
# Guardado embedding .npy de paciente 3788 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3788.npy
# Guardado embedding .npy de paciente 3789 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3789.npy
# Guardado embedding .npy de paciente 3791 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3791.npy
# Guardado embedding .npy de paciente 3792 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3792.npy
# Guardado embedding .npy de paciente 3793 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3793.npy
# Guardado embedding .npy de paciente 3795 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/3795.npy
# ...
# Guardado embedding .npy de paciente 293798 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293798.npy
# Guardado embedding .npy de paciente 293800 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293800.npy
# Guardado embedding .npy de paciente 293805 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293805.npy
# Guardado embedding .npy de paciente 293808 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293808.npy
# Guardado embedding .npy de paciente 293809 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293809.npy
# Guardado embedding .npy de paciente 293820 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293820.npy
# Guardado embedding .npy de paciente 293826 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293826.npy
# Guardado embedding .npy de paciente 293831 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293831.npy
# Guardado embedding .npy de paciente 293842 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/293842.npy
# Guardado embedding .npy de paciente 294102 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/294102.npy
# Guardado embedding .npy de paciente 294116 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/294116.npy
# Guardado embedding .npy de paciente 294139 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/294139.npy
# Guardado embedding .npy de paciente 294148 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/294148.npy
# Guardado embedding .npy de paciente 296083 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/296083.npy
# Guardado embedding .npy de paciente 296090 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/296090.npy
# Guardado embedding .npy de paciente 296665 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/296665.npy
# Guardado embedding .npy de paciente 297536 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/297536.npy
# Guardado embedding .npy de paciente 298184 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/298184.npy
# Guardado embedding .npy de paciente 298626 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/298626.npy
# Guardado embedding .npy de paciente 301568 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/301568.npy
# Guardado embedding .npy de paciente 301672 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/301672.npy
# Guardado embedding .npy de paciente 301695 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/301695.npy
# Guardado embedding .npy de paciente 301697 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/301697.npy
# Guardado embedding .npy de paciente 302526 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/302526.npy
# Guardado embedding .npy de paciente 302554 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/302554.npy
# Guardado embedding .npy de paciente 302575 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/302575.npy
# Guardado embedding .npy de paciente 305079 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/305079.npy
# Guardado embedding .npy de paciente 305889 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/305889.npy
# Guardado embedding .npy de paciente 306516 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/306516.npy
# Guardado embedding .npy de paciente 307388 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/307388.npy
# Guardado embedding .npy de paciente 307589 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/307589.npy
# Guardado embedding .npy de paciente 307656 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/307656.npy
# Guardado embedding .npy de paciente 308049 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/308049.npy
# Guardado embedding .npy de paciente 309751 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/309751.npy
# Guardado embedding .npy de paciente 309768 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/309768.npy
# Guardado embedding .npy de paciente 310998 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/310998.npy
# Guardado embedding .npy de paciente 311363 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/311363.npy
# Guardado embedding .npy de paciente 311399 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/311399.npy
# Guardado embedding .npy de paciente 311402 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/311402.npy
# Guardado embedding .npy de paciente 311540 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/311540.npy
# Guardado embedding .npy de paciente 311641 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/311641.npy
# Guardado embedding .npy de paciente 311993 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/311993.npy
# Guardado embedding .npy de paciente 312015 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/312015.npy
# Guardado embedding .npy de paciente 312222 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/312222.npy
# Guardado embedding .npy de paciente 312228 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/312228.npy
# Guardado embedding .npy de paciente 312859 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/312859.npy
# Guardado embedding .npy de paciente 312902 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/312902.npy
# Guardado embedding .npy de paciente 313162 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/313162.npy
# Guardado embedding .npy de paciente 313373 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/313373.npy
# Guardado embedding .npy de paciente 313702 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/313702.npy
# Guardado embedding .npy de paciente 313715 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/313715.npy
# Guardado embedding .npy de paciente 314660 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/314660.npy
# Guardado embedding .npy de paciente 315378 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/315378.npy
# Guardado embedding .npy de paciente 315670 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/315670.npy
# Guardado embedding .npy de paciente 317067 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/317067.npy
# Guardado embedding .npy de paciente 317824 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/317824.npy
# Guardado embedding .npy de paciente 318884 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/318884.npy
# Guardado embedding .npy de paciente 319062 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/319062.npy
# Guardado embedding .npy de paciente 319543 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/319543.npy
# Guardado embedding .npy de paciente 319735 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/319735.npy
# Guardado embedding .npy de paciente 319738 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/319738.npy
# Guardado embedding .npy de paciente 320596 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/320596.npy
# Guardado embedding .npy de paciente 320651 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/320651.npy
# Guardado embedding .npy de paciente 324862 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/324862.npy
# Guardado embedding .npy de paciente 325051 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/325051.npy
# Guardado embedding .npy de paciente 325566 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/325566.npy
# Guardado embedding .npy de paciente 325718 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/325718.npy
# Guardado embedding .npy de paciente 329289 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/329289.npy
# Guardado embedding .npy de paciente 343776 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/343776.npy
# Guardado embedding .npy de paciente 344841 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/344841.npy
# Guardado embedding .npy de paciente 347374 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/347374.npy
# Guardado embedding .npy de paciente 356510 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/356510.npy
# Guardado embedding .npy de paciente 357613 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/357613.npy
# Guardado embedding .npy de paciente 381012 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/381012.npy
# Guardado embedding .npy de paciente 383233 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/383233.npy
# Guardado embedding .npy de paciente 398222 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/398222.npy
# Guardado embedding .npy de paciente 402314 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/402314.npy
# Guardado embedding .npy de paciente 407230 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/407230.npy
# Guardado embedding .npy de paciente 408874 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/408874.npy
# Guardado embedding .npy de paciente 410567 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/410567.npy
# Guardado embedding .npy de paciente 411854 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/411854.npy
# Guardado embedding .npy de paciente 421461 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/421461.npy
# Guardado embedding .npy de paciente 423325 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/423325.npy
# Guardado embedding .npy de paciente 423380 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/423380.npy
# Guardado embedding .npy de paciente 423535 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/423535.npy
# Guardado embedding .npy de paciente 425401 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/425401.npy
# Guardado embedding .npy de paciente 427050 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/427050.npy
# Guardado embedding .npy de paciente 428521 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/428521.npy
# Guardado embedding .npy de paciente 429297 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/429297.npy
# Guardado embedding .npy de paciente 431166 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/431166.npy
# Guardado embedding .npy de paciente 431210 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/431210.npy
# Guardado embedding .npy de paciente 431490 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/431490.npy
# Guardado embedding .npy de paciente 431536 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/431536.npy
# Guardado embedding .npy de paciente 432416 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/432416.npy
# Guardado embedding .npy de paciente 439448 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/439448.npy
# Guardado embedding .npy de paciente 446160 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/446160.npy
# Guardado embedding .npy de paciente 446271 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/446271.npy
# Guardado embedding .npy de paciente 446733 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/446733.npy
# Guardado embedding .npy de paciente 447318 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/447318.npy
# Guardado embedding .npy de paciente 447557 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/447557.npy
# Guardado embedding .npy de paciente 452611 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/452611.npy
# Guardado embedding .npy de paciente 452612 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/452612.npy
# Guardado embedding .npy de paciente 459005 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/459005.npy
# Guardado embedding .npy de paciente 466157 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/466157.npy
# Guardado embedding .npy de paciente 476236 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/476236.npy
# Guardado embedding .npy de paciente 492876 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/492876.npy
# Guardado embedding .npy de paciente 496671 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/496671.npy
# Guardado embedding .npy de paciente 504436 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/504436.npy
# Guardado embedding .npy de paciente 522583 en /content/drive/MyDrive/avances/CLIP/embeddings-20251130T160205Z-1-001/embeddings/Text_pd/522583.npy

# %% [markdown]
# ## EMBEDDINGS SIN MBRS

# %%
import os
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel

# ====== RUTAS ======
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts_400_sinMBRS_ing.csv"
OUT_DIR = "/content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS"

os.makedirs(OUT_DIR, exist_ok=True)

# ====== CARGAR CSV ======
df = pd.read_csv(PROMPTS)
print("Columnas:", df.columns)

# Detectar columna ID
if "PATNO" in df.columns:
    ID_COL = "PATNO"
elif "Pat_id" in df.columns:
    ID_COL = "Pat_id"
else:
    raise ValueError("No encuentro columna ID (PATNO o Pat_id) en el CSV.")

# ====== CARGAR ClinicalBERT ======
MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME).to(device)
model.eval()

# ====== EMBEDDINGS CLS ======
def get_clinicalbert_embeddings(text_list, batch_size=8, max_length=512):
    all_embeddings = []
    with torch.no_grad():
        for i in range(0, len(text_list), batch_size):
            batch_texts = text_list[i:i + batch_size]

            encoded = tokenizer(
                batch_texts,
                padding=True,
                truncation=True,
                max_length=max_length,
                return_tensors="pt"
            )

            input_ids = encoded["input_ids"].to(device)
            attention_mask = encoded["attention_mask"].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            cls_embeddings = outputs.last_hidden_state[:, 0, :]  # [batch, hidden]

            cls_embeddings = cls_embeddings / cls_embeddings.norm(dim=-1, keepdim=True)
            all_embeddings.append(cls_embeddings.cpu())

    return torch.cat(all_embeddings, dim=0)

# ====== GUARDAR POR PACIENTE ======
for pid, sub_df in df.groupby(ID_COL):
    texts = sub_df["prompts_400_ing"].astype(str).tolist()
    if len(texts) == 0:
        continue

    emb_prompts = get_clinicalbert_embeddings(texts, batch_size=8, max_length=512)
    emb_patient = emb_prompts.mean(dim=0)
    emb_patient = emb_patient / emb_patient.norm()

    out_path = os.path.join(OUT_DIR, f"{pid}.npy")
    np.save(out_path, emb_patient.numpy())

    print(f"✅ Guardado: {out_path}")

# Liberar memoria GPU (opcional)
del model
torch.cuda.empty_cache()
print("✅ Terminado sinMBRS")
# Out:
# Columnas: Index(['PATNO', 'grupo', 'prompts_400_ing'], dtype='object')
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3007.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3010.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3014.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3018.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3020.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3021.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3023.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3024.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3025.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3026.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3027.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3028.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3052.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3054.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3056.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3058.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3059.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3060.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3061.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3066.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3067.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3068.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3076.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3077.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3078.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3080.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3081.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3086.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3088.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3089.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3105.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3107.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3108.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3110.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3111.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3113.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3116.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3118.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3119.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3120.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3122.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3123.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3124.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3125.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3126.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3127.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3128.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3129.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3130.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3131.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3132.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3133.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3134.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3150.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3154.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3162.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3164.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3166.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3167.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3168.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3173.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3174.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3175.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3176.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3177.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3178.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3179.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3180.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3181.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3182.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3184.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3185.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3186.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3187.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3190.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3203.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3205.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3207.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3209.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3210.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3211.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3212.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3214.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3218.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3220.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3223.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3224.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3225.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3226.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3227.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3228.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3229.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3230.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3231.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3232.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3233.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3234.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3236.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3251.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3252.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3253.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3254.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3263.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3265.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3267.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3268.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3269.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3272.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3275.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3278.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3279.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3280.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3281.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3282.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3284.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3285.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3288.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3289.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3290.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3305.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3307.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3308.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3309.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3311.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3312.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3313.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3314.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3321.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3322.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3323.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3325.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3327.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3328.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3329.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3330.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3331.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3332.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3333.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3352.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3354.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3359.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3360.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3364.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3365.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3366.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3367.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3371.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3372.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3373.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3374.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3375.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3376.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3377.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3378.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3380.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3383.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3385.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3386.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3387.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3392.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3400.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3403.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3406.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3407.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3409.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3413.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3415.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3416.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3417.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3418.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3419.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3420.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3421.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3422.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3423.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3429.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3430.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3431.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3432.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3433.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3434.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3435.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3436.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3439.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3440.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3442.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3443.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3444.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3445.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3446.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3447.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3448.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3451.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3454.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3455.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3459.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3461.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3462.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3467.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3469.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3470.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3471.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3472.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3473.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3474.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3475.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3476.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3482.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3500.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3501.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3502.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3504.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3505.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3506.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3507.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3509.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3510.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3513.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3514.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3516.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3522.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3528.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3530.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3532.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3533.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3534.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3535.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3542.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3552.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3556.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3557.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3558.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3559.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3561.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3562.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3564.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3567.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3574.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3575.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3577.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3584.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3585.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3586.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3587.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3588.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3589.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3591.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3592.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3593.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3601.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3603.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3604.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3605.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3606.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3607.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3608.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3609.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3612.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3616.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3617.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3618.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3621.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3622.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3623.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3625.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3626.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3628.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3629.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3630.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3631.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3632.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3633.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3634.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3638.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3650.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3652.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3653.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3654.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3657.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3659.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3660.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3661.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3663.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3664.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3665.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3666.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3700.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3701.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3703.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3704.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3705.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3706.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3707.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3708.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3709.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3710.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3711.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3752.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3753.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3757.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3758.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3760.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3762.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3763.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3764.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3766.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3770.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3771.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3773.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3774.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3775.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3776.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3777.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3778.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3780.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3781.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3785.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3787.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3788.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3789.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3791.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3792.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3793.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3795.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3800.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3802.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3808.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3814.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3815.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3818.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3819.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3822.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3823.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3824.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3825.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3827.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3828.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3829.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3830.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3831.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3832.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3833.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3834.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3835.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3837.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3838.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3856.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3858.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3863.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3866.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3867.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3868.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3869.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3870.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3900.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3903.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3904.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3905.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3906.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3909.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3910.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3911.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3914.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3916.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3951.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3953.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3954.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3957.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3958.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3960.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3961.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3962.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3963.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3964.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3970.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3971.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/3972.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4011.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4013.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4016.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4017.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4019.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4020.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4021.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4022.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4024.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4025.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4026.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4027.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4029.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4030.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4033.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4034.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4035.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4037.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4038.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4052.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4054.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4055.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4056.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4057.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4058.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4059.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4061.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4065.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4068.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4069.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4070.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4071.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4072.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4073.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4074.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4075.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4076.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4077.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4078.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4080.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4081.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4082.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4091.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4092.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4093.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4094.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4096.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4097.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4098.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4099.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4101.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4103.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4106.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4107.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4108.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4109.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4110.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4111.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4112.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4113.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4114.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4115.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4117.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4121.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4122.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4123.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4124.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4125.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4126.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4135.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4136.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/4137.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5000.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5004.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5007.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5008.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5009.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5010.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5011.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5013.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5014.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5015.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5016.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5017.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/5018.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40163.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40273.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40338.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40366.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40533.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40534.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40538.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40539.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40541.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40542.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40543.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40544.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40549.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40553.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40555.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40558.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40560.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40578.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40585.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40586.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40592.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40595.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40599.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40603.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40607.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40608.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40616.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40671.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40690.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40691.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40692.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/40693.npy
# ...
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292775.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292820.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292825.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292833.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292835.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292838.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292840.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292844.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292851.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292853.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292868.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292873.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292874.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292878.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292880.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292882.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292894.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292897.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292900.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292908.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292962.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292996.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/292998.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293033.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293040.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293044.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293063.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293075.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293175.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293212.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293217.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293370.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293372.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293379.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293404.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293445.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293454.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293463.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293487.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293595.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293596.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293632.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293633.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293641.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293650.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293681.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293695.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293703.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293711.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293726.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293740.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293759.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293767.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293770.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293774.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293778.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293781.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293787.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293793.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293795.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293798.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293800.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293805.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293808.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293809.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293820.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293831.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/293842.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/294102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/294116.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/294139.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/294148.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/296083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/296090.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/296665.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/297536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/298184.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/298626.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/301568.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/301672.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/301695.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/301697.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/302526.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/302554.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/302575.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/305079.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/305889.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/306516.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/307388.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/307589.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/307656.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/308049.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/309751.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/309768.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/310998.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/311363.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/311399.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/311402.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/311540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/311641.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/311993.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/312015.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/312222.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/312228.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/312859.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/312902.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/313162.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/313373.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/313702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/313715.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/314660.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/315378.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/315670.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/317067.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/317824.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/318884.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/319062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/319543.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/319735.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/319738.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/320596.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/320651.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/324862.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/325051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/325566.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/325718.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/329289.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/343776.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/344841.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/347374.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/356510.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/357613.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/381012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/383233.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/398222.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/402314.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/407230.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/408874.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/410567.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/411854.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/421461.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/423325.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/423380.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/423535.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/425401.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/427050.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/428521.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/429297.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/431166.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/431210.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/431490.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/431536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/432416.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/439448.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/446160.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/446271.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/446733.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/447318.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/447557.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/452611.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/452612.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/459005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/466157.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/476236.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/492876.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/496671.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/504436.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS/522583.npy
# ✅ Terminado sinMBRS

# %% [markdown]
# ## EMBEDDINGS SIN UPDRS

# %%
import os
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel

# ====== RUTAS ======
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts_400_sinUPDRS_ing.csv"
OUT_DIR = "/content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS"

os.makedirs(OUT_DIR, exist_ok=True)

# ====== CARGAR CSV ======
df = pd.read_csv(PROMPTS)
print("Columnas:", df.columns)

# Detectar columna ID
if "PATNO" in df.columns:
    ID_COL = "PATNO"
elif "Pat_id" in df.columns:
    ID_COL = "Pat_id"
else:
    raise ValueError("No encuentro columna ID (PATNO o Pat_id) en el CSV.")

# ====== CARGAR ClinicalBERT ======
MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME).to(device)
model.eval()

# ====== EMBEDDINGS CLS ======
def get_clinicalbert_embeddings(text_list, batch_size=8, max_length=512):
    all_embeddings = []
    with torch.no_grad():
        for i in range(0, len(text_list), batch_size):
            batch_texts = text_list[i:i + batch_size]

            encoded = tokenizer(
                batch_texts,
                padding=True,
                truncation=True,
                max_length=max_length,
                return_tensors="pt"
            )

            input_ids = encoded["input_ids"].to(device)
            attention_mask = encoded["attention_mask"].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            cls_embeddings = outputs.last_hidden_state[:, 0, :]  # [batch, hidden]

            cls_embeddings = cls_embeddings / cls_embeddings.norm(dim=-1, keepdim=True)
            all_embeddings.append(cls_embeddings.cpu())

    return torch.cat(all_embeddings, dim=0)

# ====== GUARDAR POR PACIENTE ======
for pid, sub_df in df.groupby(ID_COL):
    texts = sub_df["prompts_400_ing"].astype(str).tolist()
    if len(texts) == 0:
        continue

    emb_prompts = get_clinicalbert_embeddings(texts, batch_size=8, max_length=512)
    emb_patient = emb_prompts.mean(dim=0)
    emb_patient = emb_patient / emb_patient.norm()

    out_path = os.path.join(OUT_DIR, f"{pid}.npy")
    np.save(out_path, emb_patient.numpy())

    print(f"✅ Guardado: {out_path}")

# Liberar memoria GPU (opcional)
del model
torch.cuda.empty_cache()
print("✅ Terminado sinUPDRS")
# Out:
# Columnas: Index(['PATNO', 'grupo', 'prompts_400_ing'], dtype='object')
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3007.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3010.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3014.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3018.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3020.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3021.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3023.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3024.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3025.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3026.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3027.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3028.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3052.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3054.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3056.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3058.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3059.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3060.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3061.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3066.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3067.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3068.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3076.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3077.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3078.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3080.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3081.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3086.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3088.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3089.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3105.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3107.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3108.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3110.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3111.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3113.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3116.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3118.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3119.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3120.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3122.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3123.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3124.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3125.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3126.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3127.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3128.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3129.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3130.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3131.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3132.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3133.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3134.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3150.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3154.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3162.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3164.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3166.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3167.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3168.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3173.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3174.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3175.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3176.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3177.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3178.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3179.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3180.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3181.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3182.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3184.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3185.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3186.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3187.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3190.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3203.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3205.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3207.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3209.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3210.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3211.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3212.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3214.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3218.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3220.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3223.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3224.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3225.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3226.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3227.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3228.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3229.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3230.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3231.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3232.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3233.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3234.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3236.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3251.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3252.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3253.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3254.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3263.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3265.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3267.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3268.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3269.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3272.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3275.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3278.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3279.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3280.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3281.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3282.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3284.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3285.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3288.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3289.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3290.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3305.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3307.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3308.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3309.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3311.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3312.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3313.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3314.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3321.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3322.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3323.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3325.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3327.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3328.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3329.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3330.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3331.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3332.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3333.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3352.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3354.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3359.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3360.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3364.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3365.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3366.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3367.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3371.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3372.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3373.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3374.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3375.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3376.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3377.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3378.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3380.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3383.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3385.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3386.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3387.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3392.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3400.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3403.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3406.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3407.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3409.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3413.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3415.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3416.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3417.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3418.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3419.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3420.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3421.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3422.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3423.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3429.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3430.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3431.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3432.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3433.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3434.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3435.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3436.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3439.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3440.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3442.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3443.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3444.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3445.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3446.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3447.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3448.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3451.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3454.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3455.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3459.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3461.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3462.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3467.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3469.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3470.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3471.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3472.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3473.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3474.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3475.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3476.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3482.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3500.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3501.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3502.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3504.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3505.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3506.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3507.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3509.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3510.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3513.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3514.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3516.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3522.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3528.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3530.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3532.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3533.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3534.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3535.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3542.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3552.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3556.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3557.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3558.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3559.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3561.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3562.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3564.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3567.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3574.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3575.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3577.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3584.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3585.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3586.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3587.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3588.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3589.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3591.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3592.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3593.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3601.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3603.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3604.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3605.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3606.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3607.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3608.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3609.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3612.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3616.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3617.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3618.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3621.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3622.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3623.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3625.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3626.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3628.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3629.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3630.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3631.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3632.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3633.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3634.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3638.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3650.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3652.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3653.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3654.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3657.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3659.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3660.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3661.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3663.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3664.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3665.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3666.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3700.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3701.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3703.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3704.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3705.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3706.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3707.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3708.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3709.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3710.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3711.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3752.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3753.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3757.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3758.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3760.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3762.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3763.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3764.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3766.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3770.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3771.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3773.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3774.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3775.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3776.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3777.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3778.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3780.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3781.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3785.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3787.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3788.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3789.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3791.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3792.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3793.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3795.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3800.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3802.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3808.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3814.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3815.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3818.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3819.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3822.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3823.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3824.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3825.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3827.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3828.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3829.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3830.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3831.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3832.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3833.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3834.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3835.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3837.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3838.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3856.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3858.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3863.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3866.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3867.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3868.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3869.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3870.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3900.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3903.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3904.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3905.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3906.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3909.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3910.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3911.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3914.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3916.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3951.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3953.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3954.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3957.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3958.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3960.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3961.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3962.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3963.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3964.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3970.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3971.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/3972.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4011.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4013.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4016.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4017.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4019.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4020.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4021.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4022.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4024.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4025.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4026.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4027.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4029.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4030.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4033.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4034.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4035.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4037.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4038.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4052.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4054.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4055.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4056.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4057.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4058.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4059.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4061.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4065.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4068.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4069.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4070.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4071.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4072.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4073.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4074.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4075.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4076.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4077.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4078.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4080.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4081.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4082.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4091.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4092.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4093.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4094.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4096.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4097.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4098.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4099.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4101.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4103.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4106.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4107.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4108.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4109.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4110.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4111.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4112.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4113.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4114.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4115.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4117.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4121.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4122.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4123.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4124.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4125.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4126.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4135.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4136.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/4137.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5000.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5004.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5007.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5008.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5009.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5010.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5011.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5013.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5014.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5015.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5016.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5017.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/5018.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40163.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40273.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40338.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40366.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40533.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40534.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40538.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40539.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40541.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40542.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40543.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40544.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40549.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40553.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40555.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40558.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40560.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40578.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40585.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40586.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40592.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40595.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40599.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40603.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40607.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/40608.npy
# ...
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292825.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292833.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292835.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292838.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292840.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292844.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292851.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292853.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292868.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292873.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292874.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292878.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292880.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292882.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292894.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292897.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292900.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292908.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292962.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292996.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/292998.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293033.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293040.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293044.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293063.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293075.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293175.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293212.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293217.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293370.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293372.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293379.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293404.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293445.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293454.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293463.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293487.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293595.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293596.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293632.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293633.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293641.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293650.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293681.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293695.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293703.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293711.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293726.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293740.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293759.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293767.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293770.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293774.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293778.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293781.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293787.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293793.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293795.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293798.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293800.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293805.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293808.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293809.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293820.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293831.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/293842.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/294102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/294116.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/294139.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/294148.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/296083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/296090.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/296665.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/297536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/298184.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/298626.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/301568.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/301672.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/301695.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/301697.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/302526.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/302554.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/302575.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/305079.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/305889.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/306516.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/307388.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/307589.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/307656.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/308049.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/309751.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/309768.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/310998.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/311363.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/311399.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/311402.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/311540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/311641.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/311993.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/312015.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/312222.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/312228.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/312859.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/312902.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/313162.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/313373.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/313702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/313715.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/314660.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/315378.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/315670.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/317067.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/317824.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/318884.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/319062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/319543.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/319735.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/319738.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/320596.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/320651.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/324862.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/325051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/325566.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/325718.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/329289.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/343776.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/344841.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/347374.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/356510.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/357613.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/381012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/383233.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/398222.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/402314.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/407230.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/408874.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/410567.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/411854.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/421461.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/423325.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/423380.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/423535.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/425401.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/427050.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/428521.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/429297.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/431166.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/431210.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/431490.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/431536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/432416.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/439448.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/446160.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/446271.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/446733.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/447318.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/447557.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/452611.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/452612.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/459005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/466157.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/476236.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/492876.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/496671.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/504436.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS/522583.npy
# ✅ Terminado sinUPDRS

# %% [markdown]
# # EMBEDDINGS SIN H&Y

# %%
import os
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel

# ====== RUTAS ======
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts_400_sinH&Y_ing.csv"
OUT_DIR = "/content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY"

os.makedirs(OUT_DIR, exist_ok=True)

# ====== CARGAR CSV ======
df = pd.read_csv(PROMPTS)
print("Columnas:", df.columns)

# Detectar columna ID
if "PATNO" in df.columns:
    ID_COL = "PATNO"
elif "Pat_id" in df.columns:
    ID_COL = "Pat_id"
else:
    raise ValueError("No encuentro columna ID (PATNO o Pat_id) en el CSV.")

# ====== CARGAR ClinicalBERT ======
MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME).to(device)
model.eval()

# ====== EMBEDDINGS CLS ======
def get_clinicalbert_embeddings(text_list, batch_size=8, max_length=512):
    all_embeddings = []
    with torch.no_grad():
        for i in range(0, len(text_list), batch_size):
            batch_texts = text_list[i:i + batch_size]

            encoded = tokenizer(
                batch_texts,
                padding=True,
                truncation=True,
                max_length=max_length,
                return_tensors="pt"
            )

            input_ids = encoded["input_ids"].to(device)
            attention_mask = encoded["attention_mask"].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            cls_embeddings = outputs.last_hidden_state[:, 0, :]  # [batch, hidden]

            cls_embeddings = cls_embeddings / cls_embeddings.norm(dim=-1, keepdim=True)
            all_embeddings.append(cls_embeddings.cpu())

    return torch.cat(all_embeddings, dim=0)

# ====== GUARDAR POR PACIENTE ======
for pid, sub_df in df.groupby(ID_COL):
    texts = sub_df["prompts_400_ing"].astype(str).tolist()
    if len(texts) == 0:
        continue

    emb_prompts = get_clinicalbert_embeddings(texts, batch_size=8, max_length=512)
    emb_patient = emb_prompts.mean(dim=0)
    emb_patient = emb_patient / emb_patient.norm()

    out_path = os.path.join(OUT_DIR, f"{pid}.npy")
    np.save(out_path, emb_patient.numpy())

    print(f"✅ Guardado: {out_path}")

# Liberar memoria GPU (opcional)
del model
torch.cuda.empty_cache()
print("✅ Terminado sinH&Y")
# Out:
# Columnas: Index(['PATNO', 'grupo', 'prompts_400_ing'], dtype='object')
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3007.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3010.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3014.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3018.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3020.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3021.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3023.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3024.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3025.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3026.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3027.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3028.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3052.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3054.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3056.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3058.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3059.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3060.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3061.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3066.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3067.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3068.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3076.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3077.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3078.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3080.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3081.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3086.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3088.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3089.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3105.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3107.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3108.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3110.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3111.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3113.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3116.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3118.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3119.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3120.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3122.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3123.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3124.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3125.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3126.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3127.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3128.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3129.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3130.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3131.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3132.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3133.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3134.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3150.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3154.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3162.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3164.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3166.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3167.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3168.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3173.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3174.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3175.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3176.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3177.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3178.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3179.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3180.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3181.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3182.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3184.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3185.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3186.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3187.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3190.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3203.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3205.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3207.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3209.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3210.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3211.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3212.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3214.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3218.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3220.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3223.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3224.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3225.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3226.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3227.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3228.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3229.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3230.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3231.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3232.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3233.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3234.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3236.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3251.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3252.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3253.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3254.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3263.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3265.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3267.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3268.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3269.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3272.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3275.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3278.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3279.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3280.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3281.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3282.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3284.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3285.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3288.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3289.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3290.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3305.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3307.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3308.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3309.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3311.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3312.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3313.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3314.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3321.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3322.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3323.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3325.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3327.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3328.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3329.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3330.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3331.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3332.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3333.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3352.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3354.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3359.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3360.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3364.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3365.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3366.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3367.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3371.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3372.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3373.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3374.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3375.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3376.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3377.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3378.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3380.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3383.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3385.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3386.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3387.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3392.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3400.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3403.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3406.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3407.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3409.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3413.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3415.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3416.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3417.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3418.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3419.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3420.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3421.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3422.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3423.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3429.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3430.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3431.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3432.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3433.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3434.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3435.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3436.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3439.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3440.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3442.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3443.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3444.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3445.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3446.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3447.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3448.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3451.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3454.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3455.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3459.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3461.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3462.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3467.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3469.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3470.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3471.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3472.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3473.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3474.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3475.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3476.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3482.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3500.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3501.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3502.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3504.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3505.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3506.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3507.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3509.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3510.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3513.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3514.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3516.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3522.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3528.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3530.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3532.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3533.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3534.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3535.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3542.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3552.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3556.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3557.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3558.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3559.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3561.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3562.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3564.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3567.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3574.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3575.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3577.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3584.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3585.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3586.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3587.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3588.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3589.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3591.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3592.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3593.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3601.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3603.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3604.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3605.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3606.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3607.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3608.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3609.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3612.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3616.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3617.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3618.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3621.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3622.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3623.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3625.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3626.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3628.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3629.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3630.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3631.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3632.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3633.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3634.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3638.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3650.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3652.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3653.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3654.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3657.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3659.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3660.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3661.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3663.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3664.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3665.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3666.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3700.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3701.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3703.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3704.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3705.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3706.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3707.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3708.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3709.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3710.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3711.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3752.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3753.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3757.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3758.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3760.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3762.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3763.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3764.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3766.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3770.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3771.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3773.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3774.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3775.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3776.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3777.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3778.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3780.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3781.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3785.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3787.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3788.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3789.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3791.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3792.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3793.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3795.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3800.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3802.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3808.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3814.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3815.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3818.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3819.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3822.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3823.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3824.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3825.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3827.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3828.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3829.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3830.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3831.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3832.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3833.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3834.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3835.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3837.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3838.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3856.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3858.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3863.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3866.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3867.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3868.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3869.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3870.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3900.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3903.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3904.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3905.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3906.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3909.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3910.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3911.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3914.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3916.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3951.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3953.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3954.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3957.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3958.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3960.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3961.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3962.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3963.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3964.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3970.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3971.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/3972.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4011.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4013.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4016.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4017.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4019.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4020.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4021.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4022.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4024.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4025.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4026.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4027.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4029.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4030.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4033.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4034.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4035.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4037.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4038.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4052.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4054.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4055.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4056.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4057.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4058.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4059.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4061.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4065.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4068.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4069.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4070.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4071.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4072.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4073.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4074.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4075.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4076.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4077.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4078.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4080.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4081.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4082.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4091.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4092.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4093.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4094.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4096.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4097.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4098.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4099.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4101.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4103.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4106.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4107.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4108.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4109.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4110.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4111.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4112.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4113.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4114.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4115.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4117.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4121.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4122.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4123.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4124.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4125.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4126.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4135.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4136.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/4137.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5000.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5001.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5002.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5003.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5004.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5006.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5007.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5008.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5009.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5010.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5011.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5013.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5014.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5015.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5016.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5017.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/5018.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40163.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40273.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40338.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40366.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40533.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40534.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40538.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40539.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40541.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40542.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40543.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40544.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40549.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40553.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40555.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40558.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40560.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40578.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40585.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40586.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40592.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40595.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40599.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40603.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40607.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40608.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40616.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40671.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40690.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40691.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40692.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40693.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40694.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40703.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40704.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40707.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40709.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40713.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40714.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40730.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40731.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40733.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/40735.npy
# ...
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292752.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292756.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292758.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292768.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292775.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292820.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292825.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292833.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292835.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292838.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292840.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292844.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292851.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292853.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292868.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292873.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292874.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292878.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292880.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292882.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292894.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292897.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292900.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292908.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292962.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292996.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/292998.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293033.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293040.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293044.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293063.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293075.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293175.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293212.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293217.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293370.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293372.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293379.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293404.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293445.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293454.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293463.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293487.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293595.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293596.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293632.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293633.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293641.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293650.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293681.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293695.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293703.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293711.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293726.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293740.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293759.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293767.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293770.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293774.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293778.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293781.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293787.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293793.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293795.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293798.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293800.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293805.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293808.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293809.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293820.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293826.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293831.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/293842.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/294102.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/294116.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/294139.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/294148.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/296083.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/296090.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/296665.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/297536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/298184.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/298626.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/301568.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/301672.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/301695.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/301697.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/302526.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/302554.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/302575.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/305079.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/305889.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/306516.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/307388.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/307589.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/307656.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/308049.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/309751.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/309768.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/310998.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/311363.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/311399.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/311402.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/311540.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/311641.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/311993.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/312015.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/312222.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/312228.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/312859.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/312902.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/313162.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/313373.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/313702.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/313715.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/314660.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/315378.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/315670.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/317067.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/317824.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/318884.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/319062.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/319543.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/319735.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/319738.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/320596.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/320651.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/324862.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/325051.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/325566.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/325718.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/329289.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/343776.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/344841.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/347374.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/356510.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/357613.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/381012.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/383233.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/398222.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/402314.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/407230.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/408874.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/410567.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/411854.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/421461.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/423325.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/423380.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/423535.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/425401.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/427050.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/428521.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/429297.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/431166.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/431210.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/431490.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/431536.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/432416.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/439448.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/446160.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/446271.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/446733.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/447318.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/447557.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/452611.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/452612.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/459005.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/466157.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/476236.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/492876.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/496671.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/504436.npy
# ✅ Guardado: /content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinHY/522583.npy
# ✅ Terminado sinH&Y

# %% [markdown]
# # EMBEDINGS SIN MBRS

# %%
import os
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel

# ====== RUTAS ======
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts_400_sinMBRS_ing.csv"
OUT_DIR = "/content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinMBRS"

os.makedirs(OUT_DIR, exist_ok=True)

# ====== CARGAR CSV ======
df = pd.read_csv(PROMPTS)
print("Columnas:", df.columns)

# Detectar columna ID
if "PATNO" in df.columns:
    ID_COL = "PATNO"
elif "Pat_id" in df.columns:
    ID_COL = "Pat_id"
else:
    raise ValueError("No encuentro columna ID (PATNO o Pat_id) en el CSV.")

# ====== CARGAR ClinicalBERT ======
MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME).to(device)
model.eval()

# ====== EMBEDDINGS CLS ======
def get_clinicalbert_embeddings(text_list, batch_size=8, max_length=512):
    all_embeddings = []
    with torch.no_grad():
        for i in range(0, len(text_list), batch_size):
            batch_texts = text_list[i:i + batch_size]

            encoded = tokenizer(
                batch_texts,
                padding=True,
                truncation=True,
                max_length=max_length,
                return_tensors="pt"
            )

            input_ids = encoded["input_ids"].to(device)
            attention_mask = encoded["attention_mask"].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            cls_embeddings = outputs.last_hidden_state[:, 0, :]  # [batch, hidden]

            cls_embeddings = cls_embeddings / cls_embeddings.norm(dim=-1, keepdim=True)
            all_embeddings.append(cls_embeddings.cpu())

    return torch.cat(all_embeddings, dim=0)

# ====== GUARDAR POR PACIENTE ======
for pid, sub_df in df.groupby(ID_COL):
    texts = sub_df["prompts_400_ing"].astype(str).tolist()
    if len(texts) == 0:
        continue

    emb_prompts = get_clinicalbert_embeddings(texts, batch_size=8, max_length=512)
    emb_patient = emb_prompts.mean(dim=0)
    emb_patient = emb_patient / emb_patient.norm()

    out_path = os.path.join(OUT_DIR, f"{pid}.npy")
    np.save(out_path, emb_patient.numpy())

    print(f"✅ Guardado: {out_path}")

# Liberar memoria GPU (opcional)
del model
torch.cuda.empty_cache()
print("✅ Terminado sinMBRS")

# %% [markdown]
# # Embedings sin MDS-UPDRS III

# %%
import os
import torch
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel

# ====== RUTAS ======
PROMPTS = "/content/drive/MyDrive/avances/embebidos/prompts_400_sinUPDRS_ing.csv"
OUT_DIR = "/content/drive/MyDrive/avances/conferencia/embeddings_Text_pd_sinUPDRS"

os.makedirs(OUT_DIR, exist_ok=True)

# ====== CARGAR CSV ======
df = pd.read_csv(PROMPTS)
print("Columnas:", df.columns)

# Detectar columna ID
if "PATNO" in df.columns:
    ID_COL = "PATNO"
elif "Pat_id" in df.columns:
    ID_COL = "Pat_id"
else:
    raise ValueError("No encuentro columna ID (PATNO o Pat_id) en el CSV.")

# ====== CARGAR ClinicalBERT ======
MODEL_NAME = "emilyalsentzer/Bio_ClinicalBERT"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME).to(device)
model.eval()

# ====== EMBEDDINGS CLS ======
def get_clinicalbert_embeddings(text_list, batch_size=8, max_length=512):
    all_embeddings = []
    with torch.no_grad():
        for i in range(0, len(text_list), batch_size):
            batch_texts = text_list[i:i + batch_size]

            encoded = tokenizer(
                batch_texts,
                padding=True,
                truncation=True,
                max_length=max_length,
                return_tensors="pt"
            )

            input_ids = encoded["input_ids"].to(device)
            attention_mask = encoded["attention_mask"].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            cls_embeddings = outputs.last_hidden_state[:, 0, :]  # [batch, hidden]

            cls_embeddings = cls_embeddings / cls_embeddings.norm(dim=-1, keepdim=True)
            all_embeddings.append(cls_embeddings.cpu())

    return torch.cat(all_embeddings, dim=0)

# ====== GUARDAR POR PACIENTE ======
for pid, sub_df in df.groupby(ID_COL):
    texts = sub_df["prompts_400_ing"].astype(str).tolist()
    if len(texts) == 0:
        continue

    emb_prompts = get_clinicalbert_embeddings(texts, batch_size=8, max_length=512)
    emb_patient = emb_prompts.mean(dim=0)
    emb_patient = emb_patient / emb_patient.norm()

    out_path = os.path.join(OUT_DIR, f"{pid}.npy")
    np.save(out_path, emb_patient.numpy())

    print(f"✅ Guardado: {out_path}")

# Liberar memoria GPU (opcional)
del model
torch.cuda.empty_cache()
print("✅ Terminado sinUPDRS")
